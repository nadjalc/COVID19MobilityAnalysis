# %%
import pandas as pd
from datetime import datetime
import time
from itertools import islice

# %%
def append_new_row(data_frame, row):
    data_frame = data_frame.append({'lat_begin' : row['lat'], 'lng_begin' : row['lng'],
                                'lat_end' : 0, 'lng_end' : 0,
                                'ride_begin' : row['time_end'], 'ride_end' : 0,
                                'ride_time_minutes' : 0,
                                'uid_begin' : row['uid'], 'uid_end' : 0, 'standing_before_ride' : row['standing_time_minutes'],
                                'name' : row['name'], 'address' : row['address'],
                                'bike' : row['bike'], 'bike_racks' : row['bike_racks'], 
                                'bikes' : row['bikes'], 'booked_bikes' : row['booked_bikes'], 
                                'free_racks' : row['free_racks'], 'free_special_racks' : row['free_special_racks'],
                                'maintenance' : row['maintenance'], 'number' : row['number'], 
                                'place_type' : row['place_type'], 'rack_locks' : row['rack_locks'],
                                'special_racks' : row['special_racks'], 'spot' : row['spot'], 
                                'terminal_type' : row['terminal_type'], 'city' : row['city'],
                                'country_code' : row['country_code'], 'company' : row['company'],
                                'timezone' : row['timezone'],
                                'available_bikes' : row['available_bikes']}, ignore_index=True)
    return data_frame

# %% [markdown]
# ### Processes the data in order to create new column  'ride_time_minutes'
#
# #### As URL set one of the following:
# 1. 'cleaned_data_nextbike_yy-mm.csv.gz' if you want to work with original cleaned data
# 2. 'processed_data_nextbike_yy-mm.csv.gz' if you want to work with data that has GPS errors removed
#
# CHANGE NAME OF OUTPUT TO DESCRIBE THE CHOICE

# %%
url = "output_datasets/processed_data_nextbike_2020-07.csv.gz"
df = pd.read_csv(url, sep=';', low_memory=False)

# %%
fmt = '%Y-%m-%d %H:%M:%S'

# %%
pd.set_option('display.max_rows', None)

# %%
df["uid"].duplicated().any() #checking if cleaning in notebook @3 was done - there should be no duplicates
# Out:
# False

# %%
new_df = pd.DataFrame(columns= ['lat_begin', 'lng_begin', 'lat_end', 'lng_end', 'ride_begin', 'ride_end', 'ride_time_minutes', 
                                'uid_begin', 'uid_end', 'standing_before_ride', 'address', 'name', 'available_bikes', 'bike', 'bike_racks', 'bikes', 
                                'booked_bikes', 'free_racks', 'free_special_racks', 'maintenance', 'number', 
                                'place_type', 'rack_locks', 'special_racks', 'spot', 'terminal_type', 'city',
                                'country_code', 'company', 'timezone'] ) #empty dataframe with the new column structure

# %%
bikesToList = df['name'].tolist()
bikesList = list(set(bikesToList))

# %%
for name in bikesList: #repeat for each bike/bike name
    single_bike_records = df[df['name']==name]
    first_row_data = single_bike_records.iloc[0]
    last_end_time = first_row_data['time_end']

    new_df = append_new_row(new_df, first_row_data)

    for index, row in islice(single_bike_records.iterrows(), 1, None):
        t_begin = df['time_begin'][index].split('.')[0]
        t_end_previous = last_end_time.split('.')[0]    

        d1 = datetime.strptime(t_begin, fmt)
        d2 = datetime.strptime(t_end_previous, fmt)

        d1_ts = time.mktime(d1.timetuple())
        d2_ts = time.mktime(d2.timetuple())

        minsDiff = round((int(d1_ts-d2_ts) / 60), 0)

        new_df.iloc[-1, new_df.columns.get_loc('ride_time_minutes')] = minsDiff
        new_df.iloc[-1, new_df.columns.get_loc('lat_end')] = row['lat']
        new_df.iloc[-1, new_df.columns.get_loc('lng_end')] = row['lng']
        new_df.iloc[-1, new_df.columns.get_loc('ride_end')] = row['time_begin']
        new_df.iloc[-1, new_df.columns.get_loc('uid_end')] = row['uid']

        last_end_time = row['time_end']
        
        new_df = append_new_row(new_df, row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-78a9e091e908> in <module>
#      26         last_end_time = row['time_end']
#      27
# ---> 28         new_df = append_new_row(new_df, row)
#
# <ipython-input-2-3bf43a1c08c2> in append_new_row(data_frame, row)
#       1 def append_new_row(data_frame, row):
# ----> 2     data_frame = data_frame.append({'lat_begin' : row['lat'], 'lng_begin' : row['lng'],
#       3                                 'lat_end' : 0, 'lng_end' : 0,
#       4                                 'ride_begin' : row['time_end'], 'ride_end' : 0,
#       5                                 'ride_time_minutes' : 0,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7720                 combined_columns = self.columns.astype(object).append(idx_diff)
#    7721             other = (
# -> 7722                 other.reindex(combined_columns, copy=False)
#    7723                 .to_frame()
#    7724                 .T.infer_objects()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in infer_objects(self)
#    5760         # native numpy numeric types
#    5761         return self._constructor(
# -> 5762             self._mgr.convert(
#    5763                 datetime=True, numeric=False, timedelta=True, coerce=False, copy=True
#    5764             )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#     603         coerce: bool = False,
#     604     ) -> "BlockManager":
# --> 605         return self.apply(
#     606             "convert",
#     607             copy=copy,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#    2418
#    2419         if self.ndim == 2:
# -> 2420             blocks = self.split_and_operate(None, f, False)
#    2421         else:
#    2422             values = f(None, self.values.ravel(), None)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in split_and_operate(self, mask, f, inplace)
#     456             # need a new block
#     457             if m.any():
# --> 458                 nv = f(m, v, i)
#     459             else:
#     460                 nv = v if inplace else v.copy()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in f(mask, val, idx)
#    2403         def f(mask, val, idx):
#    2404             shape = val.shape
# -> 2405             values = soft_convert_objects(
#    2406                 val.ravel(),
#    2407                 datetime=datetime,
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in soft_convert_objects(values, datetime, numeric, timedelta, coerce, copy)
#    1103     if timedelta and is_object_dtype(values.dtype):
#    1104         # Object check to ensure only run if previous did not convert
# -> 1105         values = lib.maybe_convert_objects(values, convert_timedelta=True)
#    1106
#    1107     if numeric and is_object_dtype(values.dtype):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in full(shape, fill_value, dtype, order)
#     311     """
#     312     if dtype is None:
# --> 313         dtype = array(fill_value).dtype
#     314     a = empty(shape, dtype, order)
#     315     multiarray.copyto(a, fill_value, casting='unsafe')
#
# KeyboardInterrupt:

# %%
new_df.head()
# Out:
#      lat_begin  lng_begin  lat_end  lng_end                  ride_begin  \
# 0    50.972917   6.942211   50.943  6.94826  2020-07-01 08:15:01.531643
# 1    50.942994   6.948256  50.9446  6.97302  2020-07-01 09:08:02.524291
# 2    50.944647   6.973024  50.9107  6.96871  2020-07-01 14:34:02.223914
# 3    50.910694   6.968715  50.9432  6.95977  2020-07-01 20:11:01.469569
# 4    50.943172   6.959775   50.961  6.94002  2020-07-01 21:25:02.080594
# ..         ...        ...      ...      ...                         ...
# 310  50.938286   6.959007  50.9567  7.00437  2020-07-09 11:39:01.905045
# 311  50.956728   7.004370  50.9424  6.99845  2020-07-09 13:00:02.667568
# 312  50.942450   6.998455  50.9354  6.99795  2020-07-09 14:22:01.460598
# 313  50.935390   6.997951  50.9341  6.99387  2020-07-09 14:54:02.954207
# 314  50.934124   6.993870  50.9184  6.97802  2020-07-09 15:11:02.055556
#
#                        ride_end ride_time_minutes uid_begin   uid_end  \
# 0    2020-07-01 08:40:02.243662                25  31791808  31817113
# 1    2020-07-01 12:38:02.187992               210  31817113  31818971
# 2    2020-07-01 19:55:02.350584               321  31818971  31850898
# 3    2020-07-01 20:32:01.602313                21  31850898  31853330
# 4    2020-07-01 21:46:02.170175                21  31853330  31857547
# ..                          ...               ...       ...       ...
# 310  2020-07-09 12:13:01.729532                34  32224370  32230034
# 311  2020-07-09 13:12:01.977278                12  32230034  32232783
# 312  2020-07-09 14:29:01.521893                 7  32232783  32235690
# 313  2020-07-09 15:01:01.608366                 7  32235690  32237164
# 314  2020-07-09 15:39:02.195052                28  32237164  32239112
#
#      standing_before_ride address        name  bike bike_racks bikes  \
# 0                   495.0     NaN  BIKE 21739  True          0     1
# 1                    28.0     NaN  BIKE 21739  True          0     1
# 2                   116.0     NaN  BIKE 21739  True          0     1
# 3                    16.0     NaN  BIKE 21739  True          0     1
# 4                    53.0     NaN  BIKE 21739  True          0     1
# ..                    ...     ...         ...   ...        ...   ...
# 310                 155.0     NaN  BIKE 21243  True          0     1
# 311                  47.0     NaN  BIKE 21243  True          0     1
# 312                  70.0     NaN  BIKE 21243  True          0     1
# 313                  25.0     NaN  BIKE 21243  True          0     1
# 314                  10.0     NaN  BIKE 21243  True          0     1
#
#     booked_bikes free_racks free_special_racks maintenance number place_type  \
# 0              0          0                  0       False      0         12
# 1              0          0                  0       False      0         12
# 2              0          0                  0       False      0         12
# 3              0          0                  0       False      0         12
# 4              0          0                  0       False      0         12
# ..           ...        ...                ...         ...    ...        ...
# 310            0          0                  0       False      0         12
# 311            0          0                  0       False      0         12
# 312            0          0                  0       False      0         12
# 313            0          0                  0       False      0         12
# 314            0          0                  0       False      0         12
#
#     rack_locks special_racks   spot  terminal_type  city country_code  \
# 0        False             0  False            NaN  Köln           DE
# 1        False             0  False            NaN  Köln           DE
# 2        False             0  False            NaN  Köln           DE
# 3        False             0  False            NaN  Köln           DE
# 4        False             0  False            NaN  Köln           DE
# ..         ...           ...    ...            ...   ...          ...
# 310      False             0  False            NaN  Köln           DE
# 311      False             0  False            NaN  Köln           DE
# 312      False             0  False            NaN  Köln           DE
# 313      False             0  False            NaN  Köln           DE
# 314      False             0  False            NaN  Köln           DE
#
#       company       timezone available_bikes
# 0    Nextbike  Europe/Berlin            1093
# 1    Nextbike  Europe/Berlin            1162
# 2    Nextbike  Europe/Berlin            1158
# 3    Nextbike  Europe/Berlin            1153
# 4    Nextbike  Europe/Berlin            1150
# ..        ...            ...             ...
# 310  Nextbike  Europe/Berlin            1050
# 311  Nextbike  Europe/Berlin            1027
# 312  Nextbike  Europe/Berlin            1040
# 313  Nextbike  Europe/Berlin            1051
# 314  Nextbike  Europe/Berlin            1056
#
# [315 rows x 30 columns]

# %% [markdown]
# ###  Prevous code assignes 0 values to some features that should be updated trough itteration to contain acctual end values of one ride.
# ### As a result for each bike there will be one extra row that has not updated values, meaning itteration has reached the end for selected bike and 0 values were not updated.
# ### In the following cells we check for rows like that - idealy number of rows shoud match number of bikes

# %%
control_df = new_df[new_df['ride_end'] == 0]
control_df

# %%
len(bikesList)

# %%
incorrect_indexes = list(control_df.index.values)
len(incorrect_indexes)

# %%
for i in incorrect_indexes:
    if i in new_df.index.values:
        new_df.drop(i, inplace=True)

# %%
new_df = new_df.reset_index()

# %%
new_df.drop(['index'], axis=1)

# %%
new_df['ride_time_minutes'].value_counts(dropna=False)

# %%
single_bike = df[df['name']== 'BIKE 21423' ]
single_bike

# %%
single_bike_new = new_df[new_df['name']== 'BIKE 21423' ]
single_bike_new

# %%
new_df.to_csv('rides_table_nextbike_2020-07.csv', sep=';', index=False)
