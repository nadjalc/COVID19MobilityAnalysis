# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %% [markdown]
# #### Use log scale on an x axis
# #### Statistical significance - Goodnes of fit test

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2020-01.csv.gz"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 100)

# %% [markdown]
# ### Droping 1 minute rides

# %%
dfc = df[df.ride_time != 1]

# %%
distance = dfc["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="341fb320-d4f4-4d3d-8b46-b224d79aeb97" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="cbc2877f-e413-44c4-9688-a68a528e1a18" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# gamma    2971.327532 -1.651639e+06     inf     2.452295e-08
# beta     3475.329277 -1.641670e+06     inf     2.911893e-08
# norm     7602.873071 -1.510701e+06     inf     2.789368e-07
# lognorm  2564.151926 -1.428427e+06     inf     1.152879e-06
# burr     2366.167954 -1.426356e+06     inf     1.194587e-06

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'gamma': (1.4178249772268876, -19.985438180841058, 1121.371907298359)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (0.29458009780665345,
#   3.3823797708253096,
#   -3.3358525412091166e-26,
#   1.1738383318437349)}

# %%
f.get_best(method = 'bic')
# Out:
# {'gamma': (1.4178249772268876, -19.985438180841058, 1121.371907298359)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="d2d4d788-b668-4cfc-b6f7-2ccac230cd8f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="7a9b0602-69a6-453e-9e0e-c3127eda2fbb" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3475.329277 -1.641670e+06     inf     2.911893e-08
# norm      7602.873071 -1.510701e+06     inf     2.789368e-07
# bradford  2085.551656 -1.485967e+06     inf     4.272915e-07
# burr      2366.167954 -1.426356e+06     inf     1.194587e-06
# alpha     3400.872546 -1.416685e+06     inf     1.411731e-06

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="b09d7587-0518-434f-8fae-6d8920807209" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="7c1e4dea-fe5a-4a36-8fa2-1ae3c9bc33a7" style="padding-left: 10px;" text = ""/>
#                 aic           bic  kl_div  sumsquare_error
# chi2    2971.327592 -1.651639e+06     inf     2.452294e-08
# chi     4466.026898 -1.596186e+06     inf     6.382744e-08
# expon   2716.644834 -1.549406e+06     inf     1.430689e-07
# dgamma  3622.425778 -1.530640e+06     inf     1.977186e-07
# cosine  2152.886344 -1.428839e+06     inf     1.144934e-06

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="1075b39a-79b8-40d5-8fb3-90519d0f10e4" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="3dcf36a1-2a8c-4e88-9e63-63e809c999cb" style="padding-left: 10px;" text = ""/>
#                      aic           bic  kl_div  sumsquare_error
# gamma        2971.327532 -1.651639e+06     inf     2.452295e-08
# f            2611.229795 -1.636502e+06     inf     3.183432e-08
# exponnorm    2859.300073 -1.635513e+06     inf     3.238781e-08
# fatiguelife  2696.583875 -1.451611e+06     inf     7.728566e-07
# fisk         2512.496208 -1.430089e+06     inf     1.120294e-06

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="73501497-8f03-4fe5-8578-a1eeb7e830b1" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="b56a6855-98b7-46d1-b9c3-ba366c7bcfaf" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# genexpon  2722.592096 -1.549378e+06     inf     1.430565e-07
# gengamma  2721.718833 -1.549020e+06     inf     1.439701e-07
# loggamma  8101.898758 -1.508376e+06     inf     2.902961e-07
# levy      2220.399621 -1.492770e+06     inf     3.800464e-07
# lognorm   2564.151926 -1.428427e+06     inf     1.152879e-06

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="9c4d2730-d562-4df5-920a-afe8ed256216" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="431c1e1e-e108-4909-951c-7e9d93d02c5c" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# pearson3  2971.327452 -1.651639e+06     inf     2.452295e-08
# t         2902.775374 -1.531437e+06     inf     1.950194e-07
# logistic  3815.207749 -1.525453e+06     inf     2.162677e-07
# powerlaw  2079.914785 -1.459094e+06     inf     6.792712e-07
# pareto    2399.256349 -1.425637e+06     inf     1.209721e-06

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi2','gamma','genexpon','pearson3'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="6d485744-6e15-4da1-805f-ff11ee76439e" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="2f076df0-bd98-4ed5-b6f1-80965e959ebc" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# chi2      2971.327592 -1.651639e+06     inf     2.452294e-08
# gamma     2971.327532 -1.651639e+06     inf     2.452295e-08
# pearson3  2971.327452 -1.651639e+06     inf     2.452295e-08
# beta      3475.329277 -1.641670e+06     inf     2.911893e-08
# genexpon  2722.592096 -1.549378e+06     inf     1.430565e-07

# %% [markdown]
# ### 5 best distributions without 1 min drop

# %%
distance2 = df["distance"].values

# %%
f = Fitter(distance2,
           distributions=['beta','chi2','gamma','genexpon','pearson3'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="3f8e3b48-d04a-4f7d-a26a-ae45c99bb99f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="522efbe0-c444-47dd-87ad-eefa2d876f10" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# genexpon  3266.548431 -1.749005e+06     inf     5.803040e-08
# chi2      2784.085457 -1.734515e+06     inf     7.303364e-08
# beta      2829.640493 -1.732475e+06     inf     7.542015e-08
# pearson3  2782.626990 -1.730154e+06     inf     7.826005e-08
# gamma     2776.270753 -1.729044e+06     inf     7.964776e-08

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 100)

# %% [markdown]
# ### Using data without 1 min rides

# %%
rides = dfc["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="731460a7-09b4-4257-94cf-ee1f3aca93c8" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="2e127150-25d0-4e86-9b13-023d75966cb6" style="padding-left: 10px;" text = ""/>
#                  aic           bic    kl_div  sumsquare_error
# lognorm  2483.675699 -1.265464e+06  0.039899         0.000019
# beta     6662.322878 -1.226934e+06  0.094293         0.000037
# gamma    4284.555139 -1.145368e+06  0.165541         0.000152
# burr     2208.484938 -1.141062e+06  0.027943         0.000164
# norm     5981.038017 -1.023896e+06  1.212399         0.001237

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'lognorm': (1.1305539126211785, 1.8889370760227786, 16.60689097350282)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.3285459924599845,
#   26.25169978119115,
#   0.005061451576610924,
#   1.0874769467083016)}

# %%
f.get_best(method = 'bic')
# Out:
# {'lognorm': (1.1305539126211785, 1.8889370760227786, 16.60689097350282)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="c72c884d-9092-4082-8943-dd8e7fce7deb" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="2dcc8d65-e7f7-4b50-a319-4647dc54a10b" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# beta      6662.322878 -1.226934e+06  0.094293         0.000037
# burr      2208.484938 -1.141062e+06  0.027943         0.000164
# alpha     2147.312224 -1.124067e+06  0.030232         0.000220
# norm      5981.038017 -1.023896e+06  1.212399         0.001237
# bradford  1473.039355 -1.015132e+06  2.532558         0.001439

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="cb7babba-ee60-4edf-95bd-35fc3f1d398e" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="91eff1bf-b537-4d75-8482-868952f3e202" style="padding-left: 10px;" text = ""/>
#                 aic           bic    kl_div  sumsquare_error
# expon   4238.344297 -1.111035e+06  0.261794         0.000275
# dgamma  3039.319728 -1.084073e+06  0.095288         0.000438
# chi     5065.430191 -1.074225e+06  0.500561         0.000519
# chi2    1887.838510 -1.070373e+06  0.528650         0.000555
# cosine  1653.306293 -1.012961e+06  2.585916         0.001494

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="f3296d0c-3696-4445-8c88-9f5441738c55" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="1fbb2a14-ee9d-428e-9d56-a1be59ae70ed" style="padding-left: 10px;" text = ""/>
#                      aic           bic    kl_div  sumsquare_error
# fisk         2338.267954 -1.236112e+06  0.022727         0.000032
# fatiguelife  2849.929050 -1.199512e+06  0.121564         0.000060
# f            2213.603339 -1.150207e+06  0.026987         0.000140
# gamma        4284.555139 -1.145368e+06  0.165541         0.000152
# exponnorm    4368.149690 -1.120539e+06  0.244023         0.000234

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="e52377cb-a6c5-4813-bd13-b89da5499338" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="a995fe68-4582-4b53-9039-f7e2740d6a8c" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# lognorm   2483.675699 -1.265464e+06  0.039899         0.000019
# levy      1841.922725 -1.181343e+06  0.126852         0.000082
# gengamma  2722.181044 -1.144347e+06  0.142157         0.000155
# genexpon  4334.824913 -1.117274e+06  0.249867         0.000247
# loggamma  5798.544840 -1.023108e+06  1.250302         0.001254

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="50c01a1f-52a9-4a20-b1c7-274f64caa429" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="a2c18a52-8434-49f4-b144-2bb26b011d05" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# t         2308.107471 -1.228058e+06  0.027135         0.000037
# pearson3  4781.808969 -1.164014e+06  0.137524         0.000110
# pareto    1918.088659 -1.116802e+06  0.121618         0.000249
# logistic  5909.812810 -1.049372e+06  0.549178         0.000797
# powerlaw  1617.417612 -1.044421e+06  1.144680         0.000868

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['beta','expon','fisk','lognorm','t'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="7006b693-1ae8-4c14-8a30-9ae4ebee8e59" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="ec6b1fdd-33b3-4c54-84b7-8bf016246529" style="padding-left: 10px;" text = ""/>
#                  aic           bic    kl_div  sumsquare_error
# lognorm  2483.675699 -1.265464e+06  0.039899         0.000019
# fisk     2338.267954 -1.236112e+06  0.022727         0.000032
# t        2308.107471 -1.228058e+06  0.027135         0.000037
# beta     6662.322878 -1.226934e+06  0.094293         0.000037
# expon    4238.344297 -1.111035e+06  0.261794         0.000275

# %% [markdown]
# ### 5 distributions without 1 min drop

# %%
rides2 = df["ride_time"].values

# %%
f = Fitter(rides2,
           distributions=['beta','expon','fisk','lognorm','t'])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="3da20bf0-aba4-499e-8108-850d3e761e82" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="2aace1f3-0fc1-4e25-ab57-bdca36375e0f" style="padding-left: 10px;" text = ""/>
#                  aic           bic    kl_div  sumsquare_error
# fisk     2242.170929 -1.408629e+06  0.021077         0.000013
# lognorm  2370.129182 -1.366948e+06  0.043032         0.000025
# t        2333.422741 -1.333028e+06  0.024113         0.000042
# beta     5023.032335 -1.297452e+06  0.089900         0.000074
# expon    4448.059211 -1.217510e+06  0.248420         0.000264

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'fisk': (1.465930209554728, 0.18922658131307085, 15.104368555522415)}

# %%
f.get_best(method = 'aic')
# Out:
# {'fisk': (1.465930209554728, 0.18922658131307085, 15.104368555522415)}

# %%
f.get_best(method = 'bic')
# Out:
# {'fisk': (1.465930209554728, 0.18922658131307085, 15.104368555522415)}

# %% [markdown]
# # Appendix

# %%
f = Fitter(distance2,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="de3a7ad8-e621-42d8-a13d-f566a71eda9f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="92aae11f-9dab-4337-b16e-88821c7e6f2a" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# beta     2829.640493 -1.732475e+06     inf     7.542015e-08
# gamma    2776.270753 -1.729044e+06     inf     7.964776e-08
# norm     7570.463827 -1.623311e+06     inf     4.254719e-07
# burr     2373.854838 -1.582915e+06     inf     8.066929e-07
# lognorm  2578.018348 -1.567739e+06     inf     1.026182e-06

# %%
f = Fitter(rides2,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="cc705b6b-2695-4ebf-80cc-c5b903ce2d7a" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="324b14dc-603f-49fd-a948-1f492ba2beac" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# lognorm   2370.129182 -1.366948e+06  0.043032         0.000025
# burr      2404.861209 -1.366502e+06  0.027441         0.000025
# beta      5023.032335 -1.297452e+06  0.089900         0.000074
# norm      6380.032420 -1.118164e+06  1.228834         0.001274
# gamma    38303.522679 -1.103785e+06  0.628250         0.001600

# %%
get_distributions()
# Out:
# ['alpha',
#  'anglit',
#  'arcsine',
#  'argus',
#  'beta',
#  'betaprime',
#  'bradford',
#  'burr',
#  'burr12',
#  'cauchy',
#  'chi',
#  'chi2',
#  'cosine',
#  'crystalball',
#  'dgamma',
#  'dweibull',
#  'erlang',
#  'expon',
#  'exponnorm',
#  'exponpow',
#  'exponweib',
#  'f',
#  'fatiguelife',
#  'fisk',
#  'foldcauchy',
#  'foldnorm',
#  'frechet_l',
#  'frechet_r',
#  'gamma',
#  'gausshyper',
#  'genexpon',
#  'genextreme',
#  'gengamma',
#  'genhalflogistic',
#  'geninvgauss',
#  'genlogistic',
#  'gennorm',
#  'genpareto',
#  'gilbrat',
#  'gompertz',
#  'gumbel_l',
#  'gumbel_r',
#  'halfcauchy',
#  'halfgennorm',
#  'halflogistic',
#  'halfnorm',
#  'hypsecant',
#  'invgamma',
#  'invgauss',
#  'invweibull',
#  'johnsonsb',
#  'johnsonsu',
#  'kappa3',
#  'kappa4',
#  'ksone',
#  'kstwobign',
#  'laplace',
#  'levy',
#  'levy_l',
#  'levy_stable',
#  'loggamma',
#  'logistic',
#  'loglaplace',
#  'lognorm',
#  'loguniform',
#  'lomax',
#  'maxwell',
#  'mielke',
#  'moyal',
#  'nakagami',
#  'ncf',
#  'nct',
#  'ncx2',
#  'norm',
#  'norminvgauss',
#  'pareto',
#  'pearson3',
#  'powerlaw',
#  'powerlognorm',
#  'powernorm',
#  'rayleigh',
#  'rdist',
#  'recipinvgauss',
#  'reciprocal',
#  'rice',
#  'rv_continuous',
#  'rv_histogram',
#  'semicircular',
#  'skewnorm',
#  't',
#  'trapz',
#  'triang',
#  'truncexpon',
#  'truncnorm',
#  'tukeylambda',
#  'uniform',
#  'vonmises',
#  'vonmises_line',
#  'wald',
#  'weibull_max',
#  'weibull_min',
#  'wrapcauchy']
