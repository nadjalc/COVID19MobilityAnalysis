# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from itertools import islice
import statsmodels.api as sm
sns.set()
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
def parse_timestamp(el):
    b = datetime.datetime.strptime(el, fmt)
    return b

# %%
def create_date_col(df_m):
    date_lst = []
    for index, row in df_m.iterrows():
        day = str(df_m['ride_begin'][index].day)
        month = str(df_m['ride_begin'][index].month)
        year = str(df_m['ride_begin'][index].year)
        date_text = year + '-' + month + '-' + day
        date_lst.append(date_text)
    return date_lst

# %%
def trim_latlng(x):
    return round(x,4)

# %%
fmt = '%Y-%m-%d %H:%M:%S'

# %%
url = "/bigdata/jelicicna/mobility_data_2021/anlysis_data_nextbike_2021-06.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %%
df.drop('old_index', axis=1, inplace=True)

# %%
df['ride_begin'] = df['ride_begin'].map(parse_timestamp)
df['ride_end'] = df['ride_end'].map(parse_timestamp)

# %%
df['lat_begin'] = df['lat_begin'].map(trim_latlng)
df['lng_begin'] = df['lng_begin'].map(trim_latlng)
df['lat_end'] = df['lat_end'].map(trim_latlng)
df['lng_end'] = df['lng_end'].map(trim_latlng)

# %%
df['date'] = create_date_col(df)

# %%
len(df)
# Out:
# 124930

# %%
df.describe()
# Out:
#            lat_begin      lng_begin        lat_end        lng_end  \
# count  124930.000000  124930.000000  124930.000000  124930.000000
# mean       50.938632       6.949405      50.938615       6.949521
# std         0.017605       0.029617       0.017667       0.029665
# min        50.720900       6.770700      50.713000       6.770700
# 25%        50.926800       6.928200      50.926800       6.928300
# 50%        50.937500       6.946400      50.937400       6.946500
# 75%        50.950300       6.964800      50.950300       6.965000
# max        51.061400       7.157700      51.061400       7.190100
#
#            ride_time       distance     uid_begin       uid_end  \
# count  124930.000000  124930.000000  1.249300e+05  1.249300e+05
# mean       21.800312    1800.984263  4.726407e+07  4.728668e+07
# std        50.421851    1323.472517  7.175133e+05  7.162707e+05
# min         2.000000     200.000000  4.303250e+07  4.303250e+07
# 25%         7.000000     775.000000  4.668395e+07  4.670290e+07
# 50%        12.000000    1460.000000  4.728002e+07  4.730208e+07
# 75%        19.000000    2490.000000  4.789930e+07  4.792265e+07
# max       699.000000   14451.000000  4.850753e+07  4.851019e+07
#
#        standing_before_ride  available_bikes  calculated_distance
# count         124930.000000    124930.000000        124930.000000
# mean             351.492836      1497.495221         10620.047226
# std              740.985150       175.638308         21007.799524
# min                0.000000      1190.000000          1500.000000
# 25%               28.000000      1330.000000          4000.000000
# 50%              103.000000      1503.000000          6500.000000
# 75%              368.000000      1672.000000          9000.000000
# max            23116.000000      1811.000000        291500.000000

# %%
sns.set_style('whitegrid')
sns.lmplot('ride_time','distance',data=df,
           palette='coolwarm',size=13,aspect=1,fit_reg=False)
# Out:
# /ssd/jelicicna/thesisenv/lib/python3.5/site-packages/seaborn/regression.py:576: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#adding tracking of original indexes to merge tables with
df.reset_index(inplace=True)
df.rename({'index':'org_index'}, axis=1, inplace=True)

# %%
bikes = df[["name"]].drop_duplicates().reset_index(drop=True)
bikes["bike_id"]=bikes.index
bikes = bikes[["bike_id", "name"]]
bikes.head() #df with 2 columns containing bike id and corresponding bike names
# Out:
#    bike_id         name
# 0        0  BIKE 220486
# 1        1  BIKE 222136
# 2        2  BIKE 220022
# 3        3  BIKE 220155
# 4        4  BIKE 220290

# %%
#adding bike id to df
df = pd.merge(df, bikes, on='name', how='outer')

# %%
#checking for a number of unique locations
df.groupby(['lat_begin','lng_begin']).count()
# Out:
#                      org_index  lat_end  lng_end  ride_begin  ride_end  \
# lat_begin lng_begin
# 50.7209   7.0732             1        1        1           1         1
# 50.7213   7.0878             1        1        1           1         1
# 50.7220   7.0882             1        1        1           1         1
# 50.7239   7.0777             1        1        1           1         1
# 50.7260   7.0746             1        1        1           1         1
# 50.7304   7.0987             1        1        1           1         1
# 50.7318   7.0954             1        1        1           1         1
# 50.7321   7.0949             1        1        1           1         1
# 50.7343   7.1028             1        1        1           1         1
# 50.7348   7.1026             1        1        1           1         1
# 50.7535   7.0970             1        1        1           1         1
# 50.8414   6.8653             1        1        1           1         1
# 50.8472   7.0039             1        1        1           1         1
# 50.8607   7.1000             1        1        1           1         1
# 50.8617   7.0003             1        1        1           1         1
# 50.8634   6.9264             1        1        1           1         1
# 50.8651   7.0058             1        1        1           1         1
# 50.8680   7.0182             1        1        1           1         1
# 50.8685   6.9936             1        1        1           1         1
# 50.8688   7.0419             1        1        1           1         1
# 50.8691   6.9965             1        1        1           1         1
#           6.9988             1        1        1           1         1
# 50.8694   7.0422             1        1        1           1         1
#           7.0424             1        1        1           1         1
# 50.8696   7.0428             2        2        2           2         2
#           7.0432             1        1        1           1         1
# 50.8697   7.0425             1        1        1           1         1
#           7.0427             1        1        1           1         1
#           7.0432             1        1        1           1         1
# 50.8725   7.0290             1        1        1           1         1
# ...                        ...      ...      ...         ...       ...
# 51.0201   6.9197             1        1        1           1         1
#           6.9246             3        3        3           3         3
#           6.9251             1        1        1           1         1
# 51.0202   6.9198             1        1        1           1         1
# 51.0206   6.8978             1        1        1           1         1
# 51.0207   6.9254             1        1        1           1         1
#           6.9260             1        1        1           1         1
# 51.0210   6.9068             1        1        1           1         1
#           6.9246             1        1        1           1         1
# 51.0217   6.9194             1        1        1           1         1
# 51.0218   6.9300             1        1        1           1         1
# 51.0220   6.9254             1        1        1           1         1
# 51.0227   6.9046             1        1        1           1         1
# 51.0229   6.9354             1        1        1           1         1
# 51.0233   6.9316             1        1        1           1         1
# 51.0244   6.9216             1        1        1           1         1
# 51.0246   6.9222             1        1        1           1         1
# 51.0247   6.9595             1        1        1           1         1
# 51.0248   6.9244             1        1        1           1         1
# 51.0250   6.9220             1        1        1           1         1
#           6.9231             1        1        1           1         1
#           6.9232             1        1        1           1         1
# 51.0251   6.9220             1        1        1           1         1
# 51.0255   6.9220             1        1        1           1         1
# 51.0275   6.9187             1        1        1           1         1
# 51.0280   6.9166             1        1        1           1         1
#           6.9176             1        1        1           1         1
# 51.0304   6.9125             1        1        1           1         1
# 51.0308   6.9157             1        1        1           1         1
# 51.0614   6.9163             1        1        1           1         1
#
#                      ride_time  distance  uid_begin  uid_end  \
# lat_begin lng_begin
# 50.7209   7.0732             1         1          1        1
# 50.7213   7.0878             1         1          1        1
# 50.7220   7.0882             1         1          1        1
# 50.7239   7.0777             1         1          1        1
# 50.7260   7.0746             1         1          1        1
[] #a list of marked locations
new_col = []
count = 0
first_row_data = df.iloc[0]
loc_str = str([first_row_data['lat_begin'],first_row_data['lng_begin']])
new_col.append(loc_str)
locations.append(loc_str)
for index, row in islice(df.iterrows(), 1, None):
    loc_str = str([row['lat_begin'],row['lng_begin']])
    new_col.append(loc_str)
    if loc_str in locations:
        count += 1
        #print('already placed' + str(count))
    else:
        locations.append(loc_str)

# %%
#checking for the expected number of unique locations
len(locations)
# Out:
# 73300

# %%
#creating a list of unique locations
locations2 = [] #a list of marked locations
new_col = []
count = 0
first_row_data = df.iloc[0]
loc_str = str([first_row_data['lat_end'],first_row_data['lng_end']])
new_col.append(loc_str)
locations2.append(loc_str)
for index, row in islice(df.iterrows(), 1, None):
    loc_str = str([row['lat_end'],row['lng_end']])
    new_col.append(loc_str)
    if loc_str in locations2:
        count += 1
        #print('already placed' + str(count))
    else:
        locations2.append(loc_str)

# %%
len(locations2)
# Out:
# 74336

# %%
locations = list(set(locations + locations2))

# %%
type(list(locations))
# Out:
# list

# %%
df_locations = pd.DataFrame()
df_locations['latlng'] = locations

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84646 entries, 0 to 84645
# Data columns (total 2 columns):
# loc_id    84646 non-null int64
# latlng    84646 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
lst_lat = []
lst_lng = []
for index, row in df_locations.iterrows():
    string_loc = row['latlng']
    lat = float(string_loc.split('[')[1].split(',')[0])
    lng  = float(string_loc.split(']')[0].split(' ')[1])
    lst_lat.append(lat)
    lst_lng.append(lng)

# %%
df_locations['lat'] = lst_lat
df_locations['lng'] = lst_lng

# %%
out_of_range = []
for index, row in df_locations.iterrows():
    if (row['lat'] < 50.85) or (row['lat'] > 51.05):
        out_of_range.append(index)
    elif (row['lng'] < 6.80) or (row['lng'] > 7.10):
        out_of_range.append(index)

# %%
df_locations.drop(out_of_range, inplace=True)
df_locations.reset_index(drop=True, inplace=True)

# %%
df_locations.head()
# Out:
#    loc_id             latlng      lat     lng
# 0       0  [50.9312, 6.9189]  50.9312  6.9189
# 1       1  [50.9402, 7.0185]  50.9402  7.0185
# 2       2  [50.9367, 6.9443]  50.9367  6.9443
# 3       3  [50.9081, 6.9632]  50.9081  6.9632
# 4       4   [50.928, 6.9474]  50.9280  6.9474

# %%
plt.scatter(df_locations['lng'], df_locations['lat'])
plt.xlim(6.80,7.15)
plt.ylim(50.85,51.06)
plt.show()

# %%
len(df_locations)
# Out:
# 84625

# %%
df_locations.reset_index(inplace=True)
df_locations.rename({'index':'loc_id'}, axis=1, inplace=True)

# %%
df_locations.to_csv('/bigdata/jelicicna/clustering_datasets/locations_for_clustering_2021-06.csv', sep=';', index=False)

# %%
len(out_of_range)
# Out:
# 21

# %%
df_locations.iloc[out_of_range].head()
# Out:
#        loc_id             latlng      lat     lng
# 12198   12199  [50.9287, 6.9528]  50.9287  6.9528
# 16611   16613  [50.9357, 6.9852]  50.9357  6.9852
# 26053   26056  [50.9746, 6.9576]  50.9746  6.9576
# 27926   27930  [50.9399, 6.9521]  50.9399  6.9521
# 29583   29588  [50.9639, 6.9759]  50.9639  6.9759
