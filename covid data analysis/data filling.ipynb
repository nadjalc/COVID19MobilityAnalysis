# %%
import numpy as np
import pandas as pd
import matplotlib
import datetime
import time
from itertools import islice

# %%
def parse_timestamp(el):
    b = datetime.datetime.strptime(el, fmt)
    return b

# %%
fmt = '%d.%m.%Y'

# %%
def days_between(d1, d2):
    return abs((d2 - d1).days)

# %%
# Importing data on countermeasures
url = "Corona Dataset -newest version.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %%
pd.set_option('display.max_columns()', None)

# %%
df.columns
# Out:
# Index(['entry_into_force', 'amusment_venues', 'cultural_venues', 'gastronomy',
#        'essential_retail', 'non-essential_retail', 'major_events',
#        'events_and_gatherings', 'public_gatherings', 'traceability', 'tourism',
#        'traveling', 'administrative_fine', 'school_facilities',
#        'university_facilities', 'sport_facilities', 'medical_facilities',
#        'shopping_malls', 'work', 'mouth_and_nose_covering', 'curfew'],
#       dtype='object')

# %%
df.drop(['amusment_venues', 'administrative_fine', 'shopping_malls', 'work'], axis=1, inplace=True)

# %%
df
# Out:
#    entry_into_force    cultural_venues       gastronomy    essential_retail  \
# 0        16.03.2020             closed       closedw/dp          openw/meas
# 1        23.03.2020             closed       closedw/dp          openw/meas
# 2        10.04.2020             closed       closedw/dp          openw/meas
# 3        20.04.2020             closed       closedw/dp          openw/meas
# 4        01.05.2020             closed       closedw/dp          openw/meas
# 5        04.05.2020       closedw/exmz       closedw/dp          openw/meas
# 6        07.05.2020       closedw/exmz       closedw/dp          openw/meas
# 7        11.05.2020      openw/lim_100       openw/meas          openw/meas
# 8        17.05.2020      openw/lim_100       openw/meas          openw/meas
# 9        30.05.2020      openw/lim_100       openw/meas          openw/meas
# 10       15.06.2020      openw/lim_100       openw/meas          openw/meas
# 11       22.06.2020      openw/lim_100       openw/meas          openw/meas
# 12       06.08.2020      openw/lim_100       openw/meas          openw/meas
# 13       12.08.2020         openw/meas       openw/meas          openw/meas
# 14       01.09.2020         openw/meas       openw/meas          openw/meas
# 15       16.09.2020         openw/meas       openw/meas          openw/meas
# 16       01.10.2020         openw/meas       openw/meas          openw/meas
# 17       02.11.2020             closed       closedw/dp          openw/meas
# 18       09.11.2020             closed       closedw/dp          openw/meas
# 19       01.12.2020             closed       closedw/dp          openw/meas
# 20       16.12.2020             closed       closedw/dp          openw/meas
# 21       21.12.2020             closed       closedw/dp          openw/meas
# 22       23.12.2020             closed       closedw/dp          openw/meas
# 23       28.12.2020             closed       closedw/dp          openw/meas
# 24       01.01.2021             closed       closedw/dp          openw/meas
# 25       11.01.2021             closed       closedw/dp          openw/meas
# 26       20.02.2021             closed       closedw/dp          openw/meas
# 27       22.02.2021             closed       closedw/dp          openw/meas
# 28       06.03.2021             closed       closedw/dp  openw/lim_1p_10sqm
# 29       08.03.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 30       26.03.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 31       09.04.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 32       11.04.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 33       23.04.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 34       01.05.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 35       10.05.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 36       13.05.2021  openw/appointment       closedw/dp  openw/lim_1p_10sqm
# 37       28.05.2021  openw/appointment  outside_imun/dp  openw/lim_1p_10sqm
# 38       02.06.2021         openw/meas   openw/tst_vacc      openw/tst_vacc
# 39       09.06.2021         openw/meas       openw/meas      openw/tst_vacc
# 40       25.06.2021         openw/meas       openw/meas      openw/tst_vacc
#
#         non-essential_retail major_events    events_and_gatherings  \
# 0           closedw/delivery   prohibited               prohibited
# 1           closedw/delivery   prohibited               prohibited
# 2           closedw/delivery   prohibited               prohibited
# 3           closedw/delivery   prohibited               prohibited
# 4           closedw/delivery   prohibited               prohibited
# 5           closedw/delivery   prohibited               prohibited
# 6           closedw/delivery   prohibited               prohibited
# 7                 openw/meas   prohibited        pw/ex_concert_100
# 8                 openw/meas   prohibited        pw/ex_concert_100
# 9                 openw/meas   prohibited        pw/ex_concert_100
# 10                openw/meas   prohibited        pw/ex_concert_100
# 11                openw/meas   prohibited        pw/ex_concert_100
# 12                openw/meas   prohibited        pw/ex_concert_100
# 13                openw/meas   prohibited            allowedw/meas
# 14                openw/meas   prohibited            allowedw/meas
# 15                openw/meas   prohibited            allowedw/meas
# 16                openw/meas   prohibited            allowedw/meas
# 17        openw/lim_1p_10sqm   prohibited    prohibitedw/ex_trials
# 18        openw/lim_1p_10sqm   prohibited    prohibitedw/ex_trials
# 19        openw/lim_1p_10sqm   prohibited    prohibitedw/ex_trials
# 20  openw/lim_1p_10sqm_esent   prohibited    prohibitedw/ex_trials
# 21  openw/lim_1p_10sqm_esent   prohibited    prohibitedw/ex_trials
# 22  openw/lim_1p_10sqm_esent   prohibited    prohibitedw/ex_trials
# 23  openw/lim_1p_10sqm_esent   prohibited    prohibitedw/ex_trials
# 24  openw/lim_1p_10sqm_esent   prohibited    prohibitedw/ex_trials
# 25                    closed   prohibited    prohibitedw/ex_trials
# 26                    closed   prohibited    prohibitedw/ex_trials
# 27                    closed   prohibited    prohibitedw/ex_trials
# 28                    closed   prohibited    prohibitedw/ex_trials
# 29                    closed   prohibited    prohibitedw/ex_trials
# 30         openw/appointment   prohibited  prohibitedw/ex_outdoors
# 31         openw/appointment   prohibited  prohibitedw/ex_outdoors
# 32         openw/appointment   prohibited  prohibitedw/ex_outdoors
# 33          openw/app_negtst   prohibited  prohibitedw/ex_outdoors
# 34          openw/app_negtst   prohibited  prohibitedw/ex_outdoors
# 35          openw/app_negtst   prohibited  prohibitedw/ex_outdoors
# 36          openw/app_negtst   prohibited  prohibitedw/ex_outdoors
# 37             openw/lim_ppl   prohibited           allowed_250max
# 38             openw/lim_ppl   sport_1000           allowed_500max
# 39             openw/lim_ppl   sport_1000          allowed_1000max
# 40             openw/lim_ppl   sport_1000          allowed_1000max
#
#           public_gatherings traceability                  tourism  \
# 0         prohibited_over_2           no               prohibited
# 1         prohibited_over_2           no               prohibited
# 2         prohibited_over_2           no               prohibited
# 3         prohibited_over_2           no               prohibited
# 4         prohibited_over_2           no               prohibited
# 5         prohibited_over_2           no               prohibited
# 6         prohibited_over_2           no               prohibited
# 7                allowed_2h           no               prohibited
# 8                allowed_2h           no                  limited
# 9                allowed_2h          yes            allowed_only4
# 10               allowed_2h          yes            allowed_only4
# 11               allowed_2h          yes            allowed_only4
# 12               allowed_2h          yes            allowed_only4
# 13               allowed_2h          yes            allowed_only4
# 14               allowed_2h          yes  allowedw/ex_ra_med_cert
# 15               allowed_2h          yes  allowedw/ex_ra_med_cert
# 16               allowed_2h          yes  allowedw/ex_ra_med_cert
# 17              allowed_10p          yes               prohibited
# 18              allowed_10p          yes               prohibited
# 19          allowed_2h_5ppl          yes               prohibited
# 20          allowed_2h_5ppl          yes               prohibited
# 21          allowed_2h_5ppl          yes               prohibited
# 22            allowed_10ppl          yes               prohibited
# 23            allowed_10ppl          yes               prohibited
# 24          allowed_2h_5ppl          yes               prohibited
# 25            allowed_2h_1p          yes               prohibited
# 26            allowed_2h_1p          yes               prohibited
# 27            allowed_2h_1p          yes               prohibited
# 28          allowed_2h_5ppl          yes               prohibited
# 29          allowed_2h_5ppl          yes               prohibited
# 30          allowed_2h_5ppl          yes               prohibited
# 31          allowed_2h_5ppl          yes               prohibited
# 32          allowed_2h_5ppl          yes               prohibited
# 33            allowed_2h_1p          yes               prohibited
# 34            allowed_2h_1p          yes               prohibited
# 35            allowed_2h_1p          yes               prohibited
# 36            allowed_2h_1p          yes               prohibited
# 37          allowed_2h+imun          yes            limitedw/test
# 38     allowed_10ppl_3h+imm          NaN            allowedw/test
# 39  allowed_100pplw/tst_imm          NaN                  allowed
# 40  allowed_100pplw/tst_imm          NaN                  allowed
#
#                       traveling school_facilities university_facilities  \
# 0            ra_14d_limitations            closed         closedw/exlib
# 1            ra_14d_limitations            closed         closedw/exlib
# 2             ra_14d_quarantine            closed         closedw/exlib
# 3               ra_14d_nomedfac            closed         closedw/exlib
# 4               ra_14d_nomedfac            closed         closedw/exlib
# 5               ra_14d_nomedfac            closed            openw/meas
# 6             ra_14d_quarantine            closed            openw/meas
# 7             ra_14d_quarantine        openw/meas            openw/meas
# 8             o4_14d_quarantine        openw/meas            openw/meas
# 9             o4_14d_quarantine        openw/meas            openw/meas
# 10            o4_14d_quarantine        openw/meas            openw/meas
# 11            ra_14d_quarantine        openw/meas            openw/meas
# 12            ra_48test_14dqpos        openw/meas            openw/meas
# 13            ra_48test_14dqpos        openw/meas            openw/meas
# 14            ra_48test_14dqpos        openw/meas            openw/meas
# 15            ra_48test_14dqpos        openw/meas            openw/meas
# 16            ra_48test_14dqpos        openw/meas            openw/meas
# 17            ra_48test_14dqpos        openw/meas            openw/meas
# 18          ra_10dqua_reg_5test        openw/meas            openw/meas
# 19          ra_10dqua_reg_5test        openw/meas            openw/meas
# 20          ra_10dqua_reg_5test        openw/meas            openw/meas
# 21    ra_10dqua_reg_5test_mUKSA        openw/meas            openw/meas
# 22    ra_10dqua_reg_5test_mUKSA        openw/meas            openw/meas
# 23         ra_10dqua_reg_5testM        openw/meas            openw/meas
# 24         ra_10dqua_reg_5testM        openw/meas            openw/meas
# 25         ra_10dqua_reg_5testM        openw/meas          open_limited
# 26         ra_10dqua_reg_5testM        openw/meas          open_limited
# 27         ra_10dqua_reg_5testM        openw/meas          open_limited
# 28           ra_10dqua_postestM        openw/meas          open_limited
# 29         ra_10dqua_reg_5testM        openw/meas          open_limited
# 30         ra_10dqua_reg_5testM        openw/meas          open_limited
# 31              ra_testM_10dqua        openw/meas          open_limited
# 32              ra_testM_10dqua        openw/test          open_limited
# 33              ra_testM_10dqua            closed                closed
# 34          ra_testM_vac_10dqua     openw/tst_vac         openw/tst_vac
# 35  ra_testM_vac_14dqua_noshort     openw/tst_vac         openw/tst_vac
# 36               above canceled     openw/tst_vac         openw/tst_vac
# 37          ra_testM_vac_10dqua     openw/tst_vac         openw/tst_vac
# 38          ra_testM_vac_10dqua     openw/tst_vac         openw/tst_vac
# 39          ra_testM_vac_10dqua              open                  open
# 40          ra_testM_vac_10dqua              open                  open
#
#    sport_facilities         medical_facilities    mouth_and_nose_covering  \
# 0            closed             limited_visits              not_mandatory
# 1            closed             limited_visits              not_mandatory
# 2            closed             limited_visits              not_mandatory
# 3            closed             limited_visits              not_mandatory
# 4            closed             limited_visits              not_mandatory
# 5            closed             limited_visits              not_mandatory
# 6      closedw/expo             limited_visits              not_mandatory
# 7        openw/meas       allowed_visitsw/meas              not_mandatory
# 8        openw/meas       allowed_visitsw/meas              not_mandatory
# 9        openw/meas       allowed_visitsw/meas              not_mandatory
# 10       openw/meas       allowed_visitsw/meas              not_mandatory
# 11       openw/meas       allowed_visitsw/meas              not_mandatory
# 12       openw/meas       allowed_visitsw/meas              not_mandatory
# 13       openw/meas       allowed_visitsw/meas  mandatory_textile_no_dist
# 14       openw/meas       allowed_visitsw/meas  mandatory_textile_no_dist
# 15       openw/meas       allowed_visitsw/meas  mandatory_textile_no_dist
# 16       openw/meas       allowed_visitsw/meas  mandatory_textile_no_dist
# 17      openw/limit       allowed_visitsw/meas          mandatory_textile
# 18      openw/limit       allowed_visitsw/meas          mandatory_textile
# 19      openw/limit       allowed_visitsw/meas          mandatory_textile
# 20      openw/limit       allowed_visitsw/FFP2          mandatory_textile
# 21      openw/limit       allowed_visitsw/FFP2          mandatory_textile
# 22      openw/limit       allowed_visitsw/FFP2          mandatory_textile
# 23      openw/limit       allowed_visitsw/FFP2          mandatory_textile
# 24      openw/limit       allowed_visitsw/FFP2          mandatory_textile
# 25           closed       limited_visitsw/FFP2          mandatory_textile
# 26           closed  limited_visitsw/FFP2_test          mandatory_textile
# 27           closed  limited_visitsw/FFP2_test          mandatory_medical
# 28           closed  limited_visitsw/FFP2_test          mandatory_medical
# 29           closed  limited_visitsw/FFP2_test          mandatory_medical
# 30           closed  limited_visitsw/FFP2_test          mandatory_medical
# 31           closed  limited_visitsw/FFP2_test          mandatory_medical
# 32           closed  limited_visitsw/FFP2_test          mandatory_medical
# 33           closed  limited_visitsw/FFP2_test          mandatory_medical
# 34           closed  limited_visitsw/FFP2_test            mandatory_mixed
# 35           closed  limited_visitsw/FFP2_test            mandatory_mixed
# 36           closed  limited_visitsw/FFP2_test            mandatory_mixed
# 37           closed  limited_visitsw/FFP2_test            mandatory_mixed
# 38      openw/limit  limited_visitsw/FFP2_test            mandatory_mixed
# 39      openw/limit  limited_visitsw/FFP2_test            mandatory_mixed
# 40      openw/limit  limited_visitsw/mask_test          mandatory_medical
#
#             curfew
# 0               no
# 1               no
# 2               no
# 3               no
# 4               no
# 5               no
# 6               no
# 7               no
# 8               no
# 9               no
# 10              no
# 11              no
# 12              no
# 13              no
# 14              no
# 15              no
# 16              no
# 17              no
# 18              no
# 19              no
# 20              no
# 21              no
# 22              no
# 23              no
# 24              no
# 25              no
# 26              no
# 27              no
# 28              no
# 29              no
# 30              no
# 31              no
# 32              no
# 33  10pm_5am_12act
# 34  10pm_5am_12act
# 35  10pm_5am_12act
# 36  10pm_5am_12act
# 37  10pm_5am_12act
# 38              no
# 39              no
# 40              no

# %%
# Adding a row at the begining of the data frame. Data will start from January 2020
df.loc[-1] = ['01.01.2020', 'open', 'open', 'open', 'open', 'allowed',
              'allowed', 'allowed', 'no', 'allowed', 'allowed', 'open', 
              'open', 'open', 'open', 'not_mandatory', 'no']  # adding a row
df.index = df.index + 1  # shifting index
df = df.sort_index()  # sorting by index

# %%
# Adding a row at the end of the data frame. Data will end with July 2021
df.loc[42] = ['31.07.2021', 'openw/meas', 'openw/meas', 'openw/tst_vacc', 'openw/lim_ppl', 'sport_1000',
              'allowed_1000max', 'allowed_100pplw/tst_imm', 'yes', 'allowed', 'ra_testM_vac_10dqua', 'open', 
              'open', 'openw/limit', 'limited_visitsw/mask_test', 'mandatory_medical', 'no']

# %%
df['entry_into_force'] = df['entry_into_force'].map(parse_timestamp)

# %%
print(df['entry_into_force'][0].day)
print(df['entry_into_force'][0].month)
print(df['entry_into_force'][0].year)
# Out:
# 1
# 1
# 2020

# %%
# Creating a new data frame that will be filled with regulations for all dates between Jan 2020 and July 2021
new_df = pd.DataFrame(columns= ['entry_into_force', 'cultural_venues', 'gastronomy',
       'essential_retail', 'non-essential_retail', 'major_events',
       'events_and_gatherings', 'public_gatherings', 'traceability', 'tourism',
       'traveling', 'school_facilities',
       'university_facilities', 'sport_facilities', 'medical_facilities', 'mouth_and_nose_covering', 'curfew'] ) #empty dataframe

# %%
row_a = df.iloc[0]
new_df = new_df.append(row_a)

# %%
for index, row in islice(df.iterrows(), 1, None):
    n = days_between(row_a['entry_into_force'], row['entry_into_force'])
    for i in range(1,n):        
        new_df = new_df.append({ 'entry_into_force' : row_a['entry_into_force'] + datetime.timedelta(days=1), 
                'cultural_venues' : row_a['cultural_venues'], 
                'gastronomy' : row_a['gastronomy'], 'essential_retail' : row_a['essential_retail'], 
                'non-essential_retail' : row_a['non-essential_retail'], 'major_events' : row_a['major_events'], 
                'events_and_gatherings' : row_a['events_and_gatherings'], 
                'public_gatherings' : row_a['public_gatherings'], 'traceability' : row_a['traceability'], 
                'tourism' : row_a['tourism'],
                'traveling' : row_a['traveling'], 
                'school_facilities' : row_a['school_facilities'],
                'university_facilities' : row_a['university_facilities'], 'sport_facilities' : row_a['sport_facilities'], 
                'medical_facilities' : row_a['medical_facilities'],
                'mouth_and_nose_covering' : row_a['mouth_and_nose_covering'], 
                'curfew' : row_a['curfew']}, ignore_index=True)
        row_a = new_df.iloc[-1]
    new_df = new_df.append(row)
    row_a = row

# %%
new_df.reset_index(drop= True, inplace=True)

# %%
new_df.loc[70:120]
# Out:
#     entry_into_force cultural_venues  gastronomy essential_retail  \
# 70        2020-03-11            open        open             open
# 71        2020-03-12            open        open             open
# 72        2020-03-13            open        open             open
# 73        2020-03-14            open        open             open
# 74        2020-03-15            open        open             open
# 75        2020-03-16          closed  closedw/dp       openw/meas
# 76        2020-03-17          closed  closedw/dp       openw/meas
# 77        2020-03-18          closed  closedw/dp       openw/meas
# 78        2020-03-19          closed  closedw/dp       openw/meas
# 79        2020-03-20          closed  closedw/dp       openw/meas
# 80        2020-03-21          closed  closedw/dp       openw/meas
# 81        2020-03-22          closed  closedw/dp       openw/meas
# 82        2020-03-23          closed  closedw/dp       openw/meas
# 83        2020-03-24          closed  closedw/dp       openw/meas
# 84        2020-03-25          closed  closedw/dp       openw/meas
# 85        2020-03-26          closed  closedw/dp       openw/meas
# 86        2020-03-27          closed  closedw/dp       openw/meas
# 87        2020-03-28          closed  closedw/dp       openw/meas
# 88        2020-03-29          closed  closedw/dp       openw/meas
# 89        2020-03-30          closed  closedw/dp       openw/meas
# 90        2020-03-31          closed  closedw/dp       openw/meas
# 91        2020-04-01          closed  closedw/dp       openw/meas
# 92        2020-04-02          closed  closedw/dp       openw/meas
# 93        2020-04-03          closed  closedw/dp       openw/meas
# 94        2020-04-04          closed  closedw/dp       openw/meas
# 95        2020-04-05          closed  closedw/dp       openw/meas
# 96        2020-04-06          closed  closedw/dp       openw/meas
# 97        2020-04-07          closed  closedw/dp       openw/meas
# 98        2020-04-08          closed  closedw/dp       openw/meas
# 99        2020-04-09          closed  closedw/dp       openw/meas
# 100       2020-04-10          closed  closedw/dp       openw/meas
# 101       2020-04-11          closed  closedw/dp       openw/meas
# 102       2020-04-12          closed  closedw/dp       openw/meas
# 103       2020-04-13          closed  closedw/dp       openw/meas
# 104       2020-04-14          closed  closedw/dp       openw/meas
# 105       2020-04-15          closed  closedw/dp       openw/meas
# 106       2020-04-16          closed  closedw/dp       openw/meas
# 107       2020-04-17          closed  closedw/dp       openw/meas
# 108       2020-04-18          closed  closedw/dp       openw/meas
# 109       2020-04-19          closed  closedw/dp       openw/meas
# 110       2020-04-20          closed  closedw/dp       openw/meas
# 111       2020-04-21          closed  closedw/dp       openw/meas
# 112       2020-04-22          closed  closedw/dp       openw/meas
# 113       2020-04-23          closed  closedw/dp       openw/meas
# 114       2020-04-24          closed  closedw/dp       openw/meas
# 115       2020-04-25          closed  closedw/dp       openw/meas
# 116       2020-04-26          closed  closedw/dp       openw/meas
# 117       2020-04-27          closed  closedw/dp       openw/meas
# 118       2020-04-28          closed  closedw/dp       openw/meas
# 119       2020-04-29          closed  closedw/dp       openw/meas
# 120       2020-04-30          closed  closedw/dp       openw/meas
#
#     non-essential_retail major_events events_and_gatherings  \
# 70                  open      allowed               allowed
# 71                  open      allowed               allowed
# 72                  open      allowed               allowed
# 73                  open      allowed               allowed
# 74                  open      allowed               allowed
# 75      closedw/delivery   prohibited            prohibited
# 76      closedw/delivery   prohibited            prohibited
# 77      closedw/delivery   prohibited            prohibited
# 78      closedw/delivery   prohibited            prohibited
# 79      closedw/delivery   prohibited            prohibited
# 80      closedw/delivery   prohibited            prohibited
# 81      closedw/delivery   prohibited            prohibited
# 82      closedw/delivery   prohibited            prohibited
# 83      closedw/delivery   prohibited            prohibited
# 84      closedw/delivery   prohibited            prohibited
# 85      closedw/delivery   prohibited            prohibited
# 86      closedw/delivery   prohibited            prohibited
# 87      closedw/delivery   prohibited            prohibited
# 88      closedw/delivery   prohibited            prohibited
# 89      closedw/delivery   prohibited            prohibited
# 90      closedw/delivery   prohibited            prohibited
# 91      closedw/delivery   prohibited            prohibited
# 92      closedw/delivery   prohibited            prohibited
# 93      closedw/delivery   prohibited            prohibited
# 94      closedw/delivery   prohibited            prohibited
# 95      closedw/delivery   prohibited            prohibited
# 96      closedw/delivery   prohibited            prohibited
# 97      closedw/delivery   prohibited            prohibited
# 98      closedw/delivery   prohibited            prohibited
# 99      closedw/delivery   prohibited            prohibited
# 100     closedw/delivery   prohibited            prohibited
# 101     closedw/delivery   prohibited            prohibited
# 102     closedw/delivery   prohibited            prohibited
# 103     closedw/delivery   prohibited            prohibited
# 104     closedw/delivery   prohibited            prohibited
# 105     closedw/delivery   prohibited            prohibited
# 106     closedw/delivery   prohibited            prohibited
# 107     closedw/delivery   prohibited            prohibited
# 108     closedw/delivery   prohibited            prohibited
# 109     closedw/delivery   prohibited            prohibited
# 110     closedw/delivery   prohibited            prohibited
# 111     closedw/delivery   prohibited            prohibited
# 112     closedw/delivery   prohibited            prohibited
# 113     closedw/delivery   prohibited            prohibited
# 114     closedw/delivery   prohibited            prohibited
# 115     closedw/delivery   prohibited            prohibited
# 116     closedw/delivery   prohibited            prohibited
# 117     closedw/delivery   prohibited            prohibited
# 118     closedw/delivery   prohibited            prohibited
# 119     closedw/delivery   prohibited            prohibited
# 120     closedw/delivery   prohibited            prohibited
#
#      public_gatherings traceability     tourism           traveling  \
# 70             allowed           no     allowed             allowed
# 71             allowed           no     allowed             allowed
# 72             allowed           no     allowed             allowed
# 73             allowed           no     allowed             allowed
# 74             allowed           no     allowed             allowed
# 75   prohibited_over_2           no  prohibited  ra_14d_limitations
# 76   prohibited_over_2           no  prohibited  ra_14d_limitations
# 77   prohibited_over_2           no  prohibited  ra_14d_limitations
# 78   prohibited_over_2           no  prohibited  ra_14d_limitations
# 79   prohibited_over_2           no  prohibited  ra_14d_limitations
# 80   prohibited_over_2           no  prohibited  ra_14d_limitations
# 81   prohibited_over_2           no  prohibited  ra_14d_limitations
# 82   prohibited_over_2           no  prohibited  ra_14d_limitations
# 83   prohibited_over_2           no  prohibited  ra_14d_limitations
# 84   prohibited_over_2           no  prohibited  ra_14d_limitations
# 85   prohibited_over_2           no  prohibited  ra_14d_limitations
# 86   prohibited_over_2           no  prohibited  ra_14d_limitations
# 87   prohibited_over_2           no  prohibited  ra_14d_limitations
# 88   prohibited_over_2           no  prohibited  ra_14d_limitations
# 89   prohibited_over_2           no  prohibited  ra_14d_limitations
# 90   prohibited_over_2           no  prohibited  ra_14d_limitations
# 91   prohibited_over_2           no  prohibited  ra_14d_limitations
# 92   prohibited_over_2           no  prohibited  ra_14d_limitations
# 93   prohibited_over_2           no  prohibited  ra_14d_limitations
# 94   prohibited_over_2           no  prohibited  ra_14d_limitations
# 95   prohibited_over_2           no  prohibited  ra_14d_limitations
# 96   prohibited_over_2           no  prohibited  ra_14d_limitations
# 97   prohibited_over_2           no  prohibited  ra_14d_limitations
# 98   prohibited_over_2           no  prohibited  ra_14d_limitations
# 99   prohibited_over_2           no  prohibited  ra_14d_limitations
# 100  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 101  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 102  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 103  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 104  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 105  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 106  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 107  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 108  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 109  prohibited_over_2           no  prohibited   ra_14d_quarantine
# 110  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 111  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 112  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 113  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 114  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 115  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 116  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 117  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 118  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 119  prohibited_over_2           no  prohibited     ra_14d_nomedfac
# 120  prohibited_over_2           no  prohibited     ra_14d_nomedfac
#
#     school_facilities university_facilities sport_facilities  \
# 70               open                  open             open
# 71               open                  open             open
# 72               open                  open             open
# 73               open                  open             open
# 74               open                  open             open
# 75             closed         closedw/exlib           closed
# 76             closed         closedw/exlib           closed
# 77             closed         closedw/exlib           closed
# 78             closed         closedw/exlib           closed
# 79             closed         closedw/exlib           closed
# 80             closed         closedw/exlib           closed
# 81             closed         closedw/exlib           closed
# 82             closed         closedw/exlib           closed
# 83             closed         closedw/exlib           closed
# 84             closed         closedw/exlib           closed
# 85             closed         closedw/exlib           closed
# 86             closed         closedw/exlib           closed
# 87             closed         closedw/exlib           closed
# 88             closed         closedw/exlib           closed
# 89             closed         closedw/exlib           closed
# 90             closed         closedw/exlib           closed
# 91             closed         closedw/exlib           closed
# 92             closed         closedw/exlib           closed
# 93             closed         closedw/exlib           closed
# 94             closed         closedw/exlib           closed
# 95             closed         closedw/exlib           closed
# 96             closed         closedw/exlib           closed
# 97             closed         closedw/exlib           closed
# 98             closed         closedw/exlib           closed
# 99             closed         closedw/exlib           closed
# 100            closed         closedw/exlib           closed
# 101            closed         closedw/exlib           closed
# 102            closed         closedw/exlib           closed
# 103            closed         closedw/exlib           closed
# 104            closed         closedw/exlib           closed
# 105            closed         closedw/exlib           closed
# 106            closed         closedw/exlib           closed
# 107            closed         closedw/exlib           closed
# 108            closed         closedw/exlib           closed
# 109            closed         closedw/exlib           closed
# 110            closed         closedw/exlib           closed
# 111            closed         closedw/exlib           closed
# 112            closed         closedw/exlib           closed
# 113            closed         closedw/exlib           closed
# 114            closed         closedw/exlib           closed
# 115            closed         closedw/exlib           closed
# 116            closed         closedw/exlib           closed
# 117            closed         closedw/exlib           closed
# 118            closed         closedw/exlib           closed
# 119            closed         closedw/exlib           closed
# 120            closed         closedw/exlib           closed
#
#     medical_facilities mouth_and_nose_covering curfew
# 70                open           not_mandatory     no
# 71                open           not_mandatory     no
# 72                open           not_mandatory     no
# 73                open           not_mandatory     no
# 74                open           not_mandatory     no
# 75      limited_visits           not_mandatory     no
# 76      limited_visits           not_mandatory     no
# 77      limited_visits           not_mandatory     no
# 78      limited_visits           not_mandatory     no
# 79      limited_visits           not_mandatory     no
# 80      limited_visits           not_mandatory     no
# 81      limited_visits           not_mandatory     no
# 82      limited_visits           not_mandatory     no
# 83      limited_visits           not_mandatory     no
# 84      limited_visits           not_mandatory     no
# 85      limited_visits           not_mandatory     no
# 86      limited_visits           not_mandatory     no
# 87      limited_visits           not_mandatory     no
# 88      limited_visits           not_mandatory     no
# 89      limited_visits           not_mandatory     no
# 90      limited_visits           not_mandatory     no
# 91      limited_visits           not_mandatory     no
# 92      limited_visits           not_mandatory     no
# 93      limited_visits           not_mandatory     no
# 94      limited_visits           not_mandatory     no
# 95      limited_visits           not_mandatory     no
# 96      limited_visits           not_mandatory     no
# 97      limited_visits           not_mandatory     no
# 98      limited_visits           not_mandatory     no
# 99      limited_visits           not_mandatory     no
# 100     limited_visits           not_mandatory     no
# 101     limited_visits           not_mandatory     no
# 102     limited_visits           not_mandatory     no
# 103     limited_visits           not_mandatory     no
# 104     limited_visits           not_mandatory     no
# 105     limited_visits           not_mandatory     no
# 106     limited_visits           not_mandatory     no
# 107     limited_visits           not_mandatory     no
# 108     limited_visits           not_mandatory     no
# 109     limited_visits           not_mandatory     no
# 110     limited_visits           not_mandatory     no
# 111     limited_visits           not_mandatory     no
# 112     limited_visits           not_mandatory     no
# 113     limited_visits           not_mandatory     no
# 114     limited_visits           not_mandatory     no
# 115     limited_visits           not_mandatory     no
# 116     limited_visits           not_mandatory     no
# 117     limited_visits           not_mandatory     no
# 118     limited_visits           not_mandatory     no
# 119     limited_visits           not_mandatory     no
# 120     limited_visits           not_mandatory     no

# %%
new_df = new_df.rename({'entry_into_force':'date'},axis=1)

# %%
new_df
# Out:
#           date cultural_venues  gastronomy essential_retail  \
# 0   2020-01-01            open        open             open
# 1   2020-01-02            open        open             open
# 2   2020-01-03            open        open             open
# 3   2020-01-04            open        open             open
# 4   2020-01-05            open        open             open
# ..         ...             ...         ...              ...
# 573 2021-07-27      openw/meas  openw/meas   openw/tst_vacc
# 574 2021-07-28      openw/meas  openw/meas   openw/tst_vacc
# 575 2021-07-29      openw/meas  openw/meas   openw/tst_vacc
# 576 2021-07-30      openw/meas  openw/meas   openw/tst_vacc
# 577 2021-07-31      openw/meas  openw/meas   openw/tst_vacc
#
#     non-essential_retail major_events events_and_gatherings  \
# 0                   open      allowed               allowed
# 1                   open      allowed               allowed
# 2                   open      allowed               allowed
# 3                   open      allowed               allowed
# 4                   open      allowed               allowed
# ..                   ...          ...                   ...
# 573        openw/lim_ppl   sport_1000       allowed_1000max
# 574        openw/lim_ppl   sport_1000       allowed_1000max
# 575        openw/lim_ppl   sport_1000       allowed_1000max
# 576        openw/lim_ppl   sport_1000       allowed_1000max
# 577        openw/lim_ppl   sport_1000       allowed_1000max
#
#            public_gatherings traceability  tourism            traveling  \
# 0                    allowed           no  allowed              allowed
# 1                    allowed           no  allowed              allowed
# 2                    allowed           no  allowed              allowed
# 3                    allowed           no  allowed              allowed
# 4                    allowed           no  allowed              allowed
# ..                       ...          ...      ...                  ...
# 573  allowed_100pplw/tst_imm          NaN  allowed  ra_testM_vac_10dqua
# 574  allowed_100pplw/tst_imm          NaN  allowed  ra_testM_vac_10dqua
# 575  allowed_100pplw/tst_imm          NaN  allowed  ra_testM_vac_10dqua
# 576  allowed_100pplw/tst_imm          NaN  allowed  ra_testM_vac_10dqua
# 577  allowed_100pplw/tst_imm          yes  allowed  ra_testM_vac_10dqua
#
#     school_facilities university_facilities sport_facilities  \
# 0                open                  open             open
# 1                open                  open             open
# 2                open                  open             open
# 3                open                  open             open
# 4                open                  open             open
# ..                ...                   ...              ...
# 573              open                  open      openw/limit
# 574              open                  open      openw/limit
# 575              open                  open      openw/limit
# 576              open                  open      openw/limit
# 577              open                  open      openw/limit
#
#             medical_facilities mouth_and_nose_covering curfew
# 0                         open           not_mandatory     no
# 1                         open           not_mandatory     no
# 2                         open           not_mandatory     no
# 3                         open           not_mandatory     no
# 4                         open           not_mandatory     no
# ..                         ...                     ...    ...
# 573  limited_visitsw/mask_test       mandatory_medical     no
# 574  limited_visitsw/mask_test       mandatory_medical     no
# 575  limited_visitsw/mask_test       mandatory_medical     no
# 576  limited_visitsw/mask_test       mandatory_medical     no
# 577  limited_visitsw/mask_test       mandatory_medical     no
#
# [578 rows x 17 columns]

# %%
# Importing data on infection numbers -daily new infections format
url2 = "Cologne numbers.csv"
df_num = pd.read_csv(url2, sep=',', low_memory=False)

# %%
df_num = df_num.iloc[::-1]
df_num.reset_index(drop=True, inplace=True)

# %%
# Adding a row at the begining of the data frame. Data will start from January 2020
df_num.loc[-1] = ['01.01.2020', '0']  # adding a row
df_num.index = df_num.index + 1  # shifting index
df_num = df_num.sort_index()  # sorting by index

# %%
df_num
# Out:
#            date new_infections
# 0    01.01.2020              0
# 1    21.02.2020              0
# 2    22.02.2020              0
# 3    23.02.2020              0
# 4    24.02.2020              0
# ..          ...            ...
# 588  30.09.2021            101
# 589  01.10.2021             78
# 590  02.10.2021            105
# 591  03.10.2021             61
# 592  04.10.2021             26
#
# [593 rows x 2 columns]

# %%
df_num['new_infections'][2]
# Out:
# '-'

# %%
df_num['new_infections'] = df_num['new_infections'].replace('-', 0)

# %%
df_num['new_infections'].value_counts(dropna=False)
# Out:
# 0      14
# 6      14
# 18     13
# 3      11
# 2      10
#        ..
# 110     1
# 230     1
# 313     1
# 221     1
# 160     1
# Name: new_infections, Length: 254, dtype: int64

# %%
def to_integer(s):
    value = int(s)
    return value

# %%
df_num['new_infections'] = df_num['new_infections'].map(to_integer)

# %%
df_num['date'] = df_num['date'].map(parse_timestamp)

# %%
type(df_num['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
for index, row in df_num.iterrows():
    if (row['date'].year == 2021) and (row['date'].month > 7):
        df_num.drop(index, inplace=True)

# %%
new_num = pd.DataFrame(columns= ['date', 'new_infections'])

# %%
row_b = df_num.iloc[0]
new_num = new_num.append(row_b)

# %%
for index, row in islice(df_num.iterrows(), 1, None):
    n = days_between(row_b['date'], row['date'])
    for i in range(1,n):        
        new_num = new_num.append({'date' : row_b['date'] + datetime.timedelta(days=1), 
                'new_infections' : row_b['new_infections']}, ignore_index=True)
        row_b = new_num.iloc[-1]
    new_num = new_num.append(row)
    row_b = row

# %%
df_num[:20]
# Out:
#          date  new_infections
# 0  2020-01-01               0
# 1  2020-02-21               0
# 2  2020-02-22               0
# 3  2020-02-23               0
# 4  2020-02-24               0
# 5  2020-02-25               0
# 6  2020-02-26               0
# 7  2020-02-27               1
# 8  2020-02-28               0
# 9  2020-02-29               2
# 10 2020-03-01               2
# 11 2020-03-02               1
# 12 2020-03-03               6
# 13 2020-03-04               2
# 14 2020-03-05               6
# 15 2020-03-06              10
# 16 2020-03-07               1
# 17 2020-03-08               2
# 18 2020-03-09              10
# 19 2020-03-10              10

# %%
new_num.reset_index(drop=True, inplace=True)

# %%
new_num
# Out:
#           date new_infections
# 0   2020-01-01              0
# 1   2020-01-02              0
# 2   2020-01-03              0
# 3   2020-01-04              0
# 4   2020-01-05              0
# ..         ...            ...
# 573 2021-07-27             82
# 574 2021-07-28             65
# 575 2021-07-29             74
# 576 2021-07-30             50
# 577 2021-07-31             84
#
# [578 rows x 2 columns]

# %%
complete_df = pd.merge(new_df, new_num, on='date', how='outer')

# %%
complete_df.columns
# Out:
# Index(['date', 'cultural_venues', 'gastronomy', 'essential_retail',
#        'non-essential_retail', 'major_events', 'events_and_gatherings',
#        'public_gatherings', 'traceability', 'tourism', 'traveling',
#        'school_facilities', 'university_facilities', 'sport_facilities',
#        'medical_facilities', 'mouth_and_nose_covering', 'curfew',
#        'new_infections'],
#       dtype='object')

# %%
com
