# %%
from urllib.request import urlopen
import mechanicalsoup
browser = mechanicalsoup.Browser()
import re

# %%
url = "https://www.mags.nrw/coronavirus-fallzahlen-nrw"
main_page = browser.get(url)
main_page
# Out:
# <Response [200]>

# %%
main_page_html = page.soup

# %%
<div class="col-xs-10 pull-right" role="navigation" style="width: 79.5%; margin-top: 0px; padding: 4px; border: 2px; border-style: solid; border-color:#eaeaea; border-radius: 0px 0px 0px 0px;">
	<ul id="ulActiveCaseType" class="nav nav-pills disabled">
		<li id="tabFALL" class="active" title=""><a href="" data-toggle="pill">Alle Fälle</a></li>
		<li id="tabVERST" class="" title=""><a href="" data-toggle="pill" class="">Verstorbene</a></li>
		<li id="tabSUM" class="" title=""><a href="" data-toggle="pill" class="">Genesene</a></li>	
	</ul>
</div>

# %%
body = main_page_html.select('body')
body
# Out:
# [<body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-14469 node-type-article region-content i18n-de nrw-ressort">
#  <div id="skip-link">
#  <a class="element-invisible element-focusable" href="#main-content">Direkt zum Inhalt</a>
#  </div>
#  <div id="page-wrapper">
#  <div id="page">
#  <a href="#" id="top"></a>
#  <header class="with-secondary-menu" id="header" role="banner">
#  <div class="section clearfix">
#  <h1 class="element-invisible">
#              Technisches Menü        </h1>
#  <div class="region-header-menu">
#  <div class="region-menu-text region-header-responsive"><a href="javascript:void(0)">Technisches Menu
#
#  </a></div>
#  <div class="region region-header">
#  <nav class="block block-menu" id="block-menu-menu-service-menu-left" role="navigation">
#  <h2 class="element-invisible">Service Menu Left</h2>
#  <div class="content">
# ...

# %%
re.findall("Gesundheit", str(body))
# Out:
# ['Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit',
#  'Gesundheit']

# %%
unordered_list
# Out:
# [<body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-14469 node-type-article region-content i18n-de nrw-ressort">
#  <div id="skip-link">
#  <a class="element-invisible element-focusable" href="#main-content">Direkt zum Inhalt</a>
#  </div>
#  <div id="page-wrapper">
#  <div id="page">
#  <a href="#" id="top"></a>
#  <header class="with-secondary-menu" id="header" role="banner">
#  <div class="section clearfix">
#  <h1 class="element-invisible">
#              Technisches Menü        </h1>
#  <div class="region-header-menu">
#  <div class="region-menu-text region-header-responsive"><a href="javascript:void(0)">Technisches Menu
#
#  </a></div>
#  <div class="region region-header">
#  <nav class="block block-menu" id="block-menu-menu-service-menu-left" role="navigation">
#  <h2 class="element-invisible">Service Menu Left</h2>
#  <div class="content">
# ...

# %%
main_page_html.select_form('form[action="/post"]')

# %%
list(main_page_html.children)[1]
# Out:
# <html dir="ltr" lang="de" xmlns:og="http://ogp.me/ns#">
# <head>
# <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# <!--[if IE]><![endif]-->
# <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <![endif]--><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Arbeit.Gesundheit.Soziales" property="og:site_name"/>
# <meta content="https://www.mags.nrw/coronavirus-fallzahlen-nrw" property="og:url"/>
# <meta content="https://www.mags.nrw/coronavirus-fallzahlen-nrw" name="twitter:url"/>
# <link href="https://www.mags.nrw/sites/default/files/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="article" property="og:type"/>
# <meta content="summary" name="twitter:card"/>
# <link href="https://www.mags.nrw/coronavirus-fallzahlen-nrw" rel="canonical"/>
# <meta content="2021-05-28" name="dc.date.modified"/>
# <meta content="2020-03-12" name="dc.date.created"/>
# <meta content="
# ...
