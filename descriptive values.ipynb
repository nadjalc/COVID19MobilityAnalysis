# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
url_jan = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-01.csv"
url_feb = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-02.csv"
url_mar = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-03.csv"
url_apr = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-04.csv"
url_may = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-05.csv"
url_jun = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-06.csv"
url_jul = "/bigdata/jelicicna/output_datasets/limited_data_nextbike_2020-07.csv"
df_jan = pd.read_csv(url_jan, sep=';', low_memory=False)
df_feb = pd.read_csv(url_feb, sep=';', low_memory=False)
df_mar = pd.read_csv(url_mar, sep=';', low_memory=False)
df_apr = pd.read_csv(url_apr, sep=';', low_memory=False)
df_may = pd.read_csv(url_may, sep=';', low_memory=False)
df_jun = pd.read_csv(url_jun, sep=';', low_memory=False)
df_jul = pd.read_csv(url_jul, sep=';', low_memory=False)

# %%
pd.set_option('display.max_columns()', None)

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %% [markdown]
# ## Quantitative analysis

# %%
df_jan.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  53259.000000  53259.000000  53259.000000  53259.000000  53259.000000
# mean   32019.271916     50.940963      6.949696     50.940982      6.949573
# std    18527.881014      0.019349      0.033312      0.019414      0.033367
# min        0.000000     50.732188      6.833255     50.733653      6.772942
# 25%    15934.500000     50.927299      6.924878     50.927327      6.924801
# 50%    32037.000000     50.938865      6.946697     50.938938      6.946535
# 75%    48089.500000     50.953877      6.970407     50.953933      6.970251
# max    64090.000000     51.017990      7.097361     51.028600      7.101521
#
#           ride_time      distance     uid_begin       uid_end  \
# count  53259.000000  53259.000000  5.325900e+04  5.325900e+04
# mean      31.893558   1670.938020  2.701374e+07  2.702923e+07
# std       51.600339   1240.207784  4.328948e+05  3.187221e+05
# ...

# %%
df_feb.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  44869.000000  44869.000000  44869.000000  44869.000000  44869.000000
# mean   27226.371281     50.940278      6.948406     50.940330      6.948330
# std    15733.204752      0.019298      0.032474      0.019360      0.032551
# min        0.000000     50.858236      6.827578     50.847919      6.827578
# 25%    13646.000000     50.926789      6.924770     50.926790      6.924551
# 50%    27073.000000     50.938365      6.945414     50.938421      6.945441
# 75%    40853.000000     50.952910      6.966455     50.952951      6.966455
# max    54432.000000     51.052009      7.048083     51.058823      7.062061
#
#           ride_time      distance     uid_begin       uid_end  \
# count  44869.000000  44869.000000  4.486900e+04  4.486900e+04
# mean      33.163498   1689.970848  2.776254e+07  2.777648e+07
# std       53.204168   1251.263623  3.924760e+05  2.036172e+05
# ...

# %%
df_mar.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  39663.000000  39663.000000  39663.000000  39663.000000  39663.000000
# mean   24373.462925     50.940555      6.949739     50.940613      6.949784
# std    14037.583746      0.020643      0.033177      0.020771      0.033231
# min        0.000000     50.846436      6.826575     50.846363      6.826575
# 25%    12214.500000     50.926730      6.925519     50.926742      6.925568
# 50%    24388.000000     50.938894      6.947443     50.938995      6.947613
# 75%    36554.000000     50.953785      6.969869     50.953968      6.969951
# max    48538.000000     51.484498      7.086521     51.496484      7.093986
#
#           ride_time      distance     uid_begin       uid_end  \
# count  39663.000000  39663.000000  3.966300e+04  3.966300e+04
# mean      37.601392   1863.872652  2.846728e+07  2.848070e+07
# std       57.317828   1394.934116  4.050043e+05  2.860357e+05
# ...

# %%
df_apr.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  45057.000000  45057.000000  45057.000000  45057.000000  45057.000000
# mean   28997.568813     50.940574      6.948778     50.940628      6.948708
# std    16901.663121      0.020977      0.032518      0.021145      0.032596
# min        0.000000     50.709290      6.813468     50.692742      6.813468
# 25%    14125.000000     50.926462      6.925340     50.926456      6.925238
# 50%    28931.000000     50.938751      6.947109     50.938838      6.947034
# 75%    43813.000000     50.954641      6.968562     50.954762      6.968511
# max    58227.000000     51.048648      7.165486     51.048567      7.165486
#
#           ride_time      distance     uid_begin       uid_end  \
# count  45057.000000  45057.000000  4.505700e+04  4.505700e+04
# mean      42.815900   2087.415252  2.911511e+07  2.912643e+07
# std       61.042178   1552.291260  4.087198e+05  3.610272e+05
# ...

# %%
df_may.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  56505.000000  56505.000000  56505.000000  56505.000000  56505.000000
# mean   35162.033236     50.940288      6.948569     50.940270      6.948507
# std    20254.371919      0.020441      0.031708      0.020588      0.031765
# min        0.000000     50.737556      6.779204     50.732689      6.779655
# 25%    17601.000000     50.926368      6.925789     50.926287      6.925780
# 50%    34924.000000     50.938382      6.946484     50.938357      6.946416
# 75%    52957.000000     50.953997      6.966291     50.954018      6.966325
# max    70000.000000     51.461867      7.101909     51.461791      7.101909
#
#           ride_time      distance     uid_begin       uid_end  \
# count  56505.000000  56505.000000  5.650500e+04  5.650500e+04
# mean      41.117122   2080.412548  2.995094e+07  2.996351e+07
# std       60.981451   1510.400908  3.990966e+05  3.571576e+05
# ...

# %%
df_jun.describe()
# Out:
#          old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  58334.00000  58334.000000  58334.000000  58334.000000  58334.000000
# mean   35760.22558     50.940228      6.948676     50.940281      6.948651
# std    20737.46577      0.020771      0.032162      0.020916      0.032240
# min        1.00000     50.736577      6.808207     50.738419      6.765073
# 25%    17794.25000     50.926719      6.925829     50.926689      6.925768
# 50%    35759.50000     50.938252      6.946669     50.938275      6.946697
# 75%    53746.75000     50.953113      6.966545     50.953209      6.966593
# max    71584.00000     51.461947      7.145875     51.462036      7.145875
#
#           ride_time      distance     uid_begin       uid_end  \
# count  58334.000000  58334.000000  5.833400e+04  5.833400e+04
# mean      40.990160   2092.978126  3.110703e+07  3.112332e+07
# std       61.831935   1523.939928  5.612432e+05  4.748900e+05
# ...

# %%
df_jul.describe()
# Out:
#           old_index     lat_begin     lng_begin       lat_end       lng_end  \
# count  55446.000000  55446.000000  55446.000000  55446.000000  55446.000000
# mean   34244.168254     50.940341      6.949334     50.940367      6.949313
# std    19721.227050      0.020041      0.032446      0.020108      0.032561
# min        3.000000     50.724577      6.810966     50.724577      6.810966
# 25%    17345.250000     50.927075      6.926341     50.927101      6.926328
# 50%    34271.500000     50.938425      6.947703     50.938421      6.947670
# 75%    51521.750000     50.952835      6.968769     50.952896      6.968832
# max    68287.000000     51.052740      7.124766     51.050681      7.174642
#
#           ride_time      distance     uid_begin       uid_end  \
# count  55446.000000  55446.000000  5.544600e+04  5.544600e+04
# mean      42.196101   2059.087472  3.261859e+07  3.263650e+07
# std       63.160529   1492.749689  6.862819e+05  6.272077e+05
# ...
