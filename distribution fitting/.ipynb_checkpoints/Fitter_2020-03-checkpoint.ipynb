# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2020-03.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 150)

# %%
distance = df["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="a7a4e749-d476-4d5a-8365-43f270ee5ce6" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="55b9a115-e9fe-413b-b0ab-765020834294" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# gamma    3588.422822 -1.141836e+06     inf     1.503371e-08
# beta     3855.598984 -1.137118e+06     inf     1.691546e-08
# burr     3276.854643 -1.032694e+06     inf     2.314564e-07
# norm     5669.434096 -9.923482e+05     inf     6.363230e-07
# lognorm  3626.224333 -9.342713e+05     inf     2.725631e-06

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'gamma': (1.2969983424109828, 198.24982094591604, 1286.4725537428435)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.386039349594793,
#   26952.51853877856,
#   -68.38806625092207,
#   0.6412679102814483)}

# %%
f.get_best(method = 'bic')
# Out:
# {'gamma': (1.2969983424109828, 198.24982094591604, 1286.4725537428435)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="9367f0e4-296a-4c1a-9002-9aa66ffdd717" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="165c1d29-79e1-4503-b64c-41e1e7372341" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3855.598984 -1.137118e+06     inf     1.691546e-08
# burr      3276.854643 -1.032694e+06     inf     2.314564e-07
# alpha     3269.888503 -9.998937e+05     inf     5.265795e-07
# norm      5669.434096 -9.923482e+05     inf     6.363230e-07
# bradford  2950.372245 -9.872294e+05     inf     7.231989e-07

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="fa1c0521-d4b2-48c5-9132-09a5adb2e295" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="45bdfbe8-c55c-4e56-95b5-7d672d172134" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# chi      4324.486137 -1.078351e+06     inf     7.375865e-08
# expon    3455.118740 -1.053415e+06     inf     1.377988e-07
# dgamma   4142.119566 -1.002585e+06     inf     4.922460e-07
# cosine   3099.450333 -9.495648e+05     inf     1.858581e-06
# chi2    72096.218665 -9.297491e+05     inf     3.052605e-06

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="b3f74b76-5c04-450f-a7c3-7eb6a0d6f792" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="7c033c32-ff53-441f-ae3b-9b85b2700743" style="padding-left: 10px;" text = ""/>
#                      aic           bic  kl_div  sumsquare_error
# gamma        3588.422822 -1.141836e+06     inf     1.503371e-08
# fatiguelife  3494.030511 -1.092740e+06     inf     5.143361e-08
# exponnorm    3489.060380 -1.086123e+06     inf     6.070864e-08
# f            3549.686451 -1.075013e+06     inf     8.017144e-08
# fisk         3327.506286 -1.060946e+06     inf     1.140747e-07

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="f6133ff3-ed1a-4b51-845a-ca86550f3642" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="0c85cc7a-eeb2-4135-b6bf-8b0364cf9d6b" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# genexpon  3461.312758 -1.053347e+06     inf     1.379224e-07
# gengamma  3252.290791 -1.030567e+06     inf     2.441230e-07
# levy      3183.616458 -1.003791e+06     inf     4.777201e-07
# loggamma  5633.562151 -9.922735e+05     inf     6.373455e-07
# lognorm   3626.224333 -9.342713e+05     inf     2.725631e-06

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="1fc263b8-5382-428f-b999-4cd66a7138c4" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="67eda97b-b234-4e29-b5cc-057f61b6ef1e" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# pearson3  3588.422753 -1.141836e+06     inf     1.503371e-08
# logistic  4222.783800 -9.983116e+05     inf     5.480155e-07
# t         3908.915321 -9.914082e+05     inf     6.513138e-07
# powerlaw  2957.307040 -9.652506e+05     inf     1.254289e-06
# pareto    3292.629247 -9.203178e+05     inf     3.866229e-06

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi','gamma', 'gengamma', 'pearson3'], bins=150)

f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="b26de17b-56da-45be-9801-31d4355c13a1" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="ff2da280-d8e7-4d77-a7a5-9df87f2fbda6" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# pearson3  3588.422753 -1.141836e+06     inf     1.503371e-08
# gamma     3588.422822 -1.141836e+06     inf     1.503371e-08
# beta      3855.598984 -1.137118e+06     inf     1.691546e-08
# chi       4324.486137 -1.078351e+06     inf     7.375865e-08
# gengamma  3252.290791 -1.030567e+06     inf     2.441230e-07

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 140)

# %%
rides = df["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="5087f665-5213-4237-b001-7ef5bac30f18" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="df34d1e5-2424-4f51-934c-1f1ecdd44e83" style="padding-left: 10px;" text = ""/>
#                  aic            bic    kl_div  sumsquare_error
# burr     2592.356743 -838651.925187  0.024300         0.000030
# lognorm  2767.486586 -751150.858106  0.074353         0.000268
# gamma    3285.031800 -696982.885777  0.227774         0.001041
# beta     3284.038476 -696585.827666  0.231600         0.001051
# norm     5220.746142 -655968.376623  0.851230         0.002908

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'burr': (1.331257493959253,
#   61.74086053617003,
#   -0.1570333513902774,
#   0.6547386260746209)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.331257493959253,
#   61.74086053617003,
#   -0.1570333513902774,
#   0.6547386260746209)}

# %%
f.get_best(method = 'bic')
# Out:
# {'burr': (1.331257493959253,
#   61.74086053617003,
#   -0.1570333513902774,
#   0.6547386260746209)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="34aa5e46-9aec-4ba8-92fa-287e8965c06f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="39dcda42-362a-488d-9d87-ac115a8da0b7" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# burr      2592.356743 -838651.925187  0.024300         0.000030
# alpha     2498.318611 -790531.460450  0.028744         0.000100
# beta      3284.038476 -696585.827666  0.231600         0.001051
# norm      5220.746142 -655968.376623  0.851230         0.002908
# bradford  1925.120477 -654243.216976  1.342546         0.003036

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="87e1aaa9-03b3-41b2-908d-1c297b431a45" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="95a8f9df-d426-4b26-9511-3bb72cecfaf5" style="padding-left: 10px;" text = ""/>
#                 aic            bic    kl_div  sumsquare_error
# expon   3534.013331 -702419.116470  0.228281         0.000908
# dgamma  3685.868906 -702206.033242  0.135054         0.000913
# chi2    3267.191485 -696753.219364  0.229282         0.001047
# chi     3344.065156 -677229.280215  0.407939         0.001707
# cosine  2097.303203 -645057.078554  1.796543         0.003823

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="397f234e-b627-4811-9b01-1661d1ad0bf6" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="74721f77-4afe-4052-9f47-62b89aeebac4" style="padding-left: 10px;" text = ""/>
#                      aic            bic    kl_div  sumsquare_error
# f            2590.676181 -832376.627999  0.025714         0.000035
# fisk         2708.403107 -770556.112551  0.048930         0.000165
# fatiguelife  2896.431319 -732076.108012  0.127441         0.000432
# exponnorm    3663.154774 -717093.502190  0.200221         0.000629
# gamma        3285.031800 -696982.885777  0.227774         0.001041

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="0752407a-fd50-4bb7-8836-752d9997cab5" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="4625403b-df3f-4b7f-b30d-84a3cc66eb5b" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# lognorm   2767.486586 -751150.858106  0.074353         0.000268
# genexpon  3539.943739 -702386.037234  0.228289         0.000908
# levy      2261.248153 -699769.360303  0.197663         0.000971
# gengamma  2896.943543 -697490.574052  0.207357         0.001027
# loggamma  4875.138609 -655033.756536  0.876450         0.002977

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="dd393837-3cc8-4354-8af1-eebac2cf0a13" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="759821fd-473a-4e7f-b1f7-4349c880382e" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# t         2792.853781 -732218.258011  0.075019         0.000430
# pearson3  3298.508386 -697221.549546  0.226860         0.001034
# logistic  4832.072494 -671951.837977  0.450734         0.001949
# powerlaw  1998.325147 -663565.454703  0.911571         0.002404
# pareto    2378.575560 -642262.351737  0.541507         0.004099

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['alpha','burr','expon', 'f', 't'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="b9311c40-58d0-4e4a-865f-93efb8c309c7" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="71cb342f-0234-4e2e-be13-56832cfaf3fe" style="padding-left: 10px;" text = ""/>
#                aic            bic    kl_div  sumsquare_error
# burr   2592.356743 -838651.925187  0.024300         0.000030
# f      2590.676181 -832376.627999  0.025714         0.000035
# alpha  2498.318611 -790531.460450  0.028744         0.000100
# t      2792.853781 -732218.258011  0.075019         0.000430
# expon  3534.013331 -702419.116470  0.228281         0.000908
