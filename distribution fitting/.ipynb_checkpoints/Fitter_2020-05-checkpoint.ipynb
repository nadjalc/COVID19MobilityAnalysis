# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2020-04.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 100)

# %%
distance = df["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins=100)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="e9766b1a-72f8-4a32-8583-4d029f897de6" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="b07ad987-084d-4ac5-9769-fa8375e9893b" style="padding-left: 10px;" text = ""/>

# %%
f.get_best(method = 'sumsquare_error')

# %%
f.get_best(method = 'aic')

# %%
f.get_best(method = 'bic')

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'], bins=100)
f.fit()
f.summary()

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins=100)
f.fit()
f.summary()

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins=100)
f.fit()
f.summary()

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins=100)
f.fit()
f.summary()

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins=100)
f.fit()
f.summary()

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi','gamma', 'gengamma', 'pearson3'], bins=100)

f.fit()
f.summary()

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 140)

# %%
rides = df["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins = 100)
f.fit()
f.summary()

# %%
f.get_best(method = 'sumsquare_error')

# %%
f.get_best(method = 'aic')

# %%
f.get_best(method = 'bic')

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'], bins = 100)
f.fit()
f.summary()

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins = 100)
f.fit()
f.summary()

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins = 100)
f.fit()
f.summary()

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins = 100)
f.fit()
f.summary()

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins = 100)
f.fit()
f.summary()

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['alpha','burr','lognorm'], bins = 100)
f.fit()
f.summary()
