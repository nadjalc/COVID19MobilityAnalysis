# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2020-07.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 150)

# %%
distance = df["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="fc9a43b7-6833-4336-a572-731b52f60a4f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="8e290e30-6fab-4eae-bd30-5f2b797b097f" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# beta     3633.421722 -1.629756e+06     inf     1.230182e-08
# gamma    3631.421535 -1.629766e+06     inf     1.230184e-08
# lognorm  3477.702270 -1.533178e+06     inf     6.920089e-08
# burr     3461.767817 -1.524032e+06     inf     8.148121e-08
# norm     5732.740158 -1.436259e+06     inf     3.916535e-07

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'beta': (1.4237601377143523,
#   8920906.663680024,
#   192.99740852396735,
#   11709781843.123531)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (2.9593540030672822,
#   0.5353556387703513,
#   -12.904247814739804,
#   2416.185780909232)}

# %%
f.get_best(method = 'bic')
# Out:
# {'gamma': (1.4237605032829275, 192.9973887974329, 1312.6218915085449)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="3161209d-78f0-4a00-9be9-553dcf95a392" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="9b84a91b-bfc3-49c4-9e05-0452d247e6bf" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3633.421722 -1.629756e+06     inf     1.230182e-08
# burr      3461.767817 -1.524032e+06     inf     8.148121e-08
# norm      5732.740158 -1.436259e+06     inf     3.916535e-07
# alpha     3291.278273 -1.411391e+06     inf     6.108782e-07
# bradford  2906.844125 -1.377762e+06     inf     1.114627e-06

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="4d4abb87-f3c1-4483-8fc0-9647de94e8c9" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="67dea131-353a-4361-abfc-bf6a2b54bf3b" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# chi       4276.436534 -1.572860e+06       inf     3.403521e-08
# expon     3452.417866 -1.482686e+06       inf     1.707381e-07
# dgamma    4168.698834 -1.448908e+06       inf     3.123079e-07
# cosine    3121.329430 -1.362391e+06       inf     1.467533e-06
# chi2    394759.991809 -1.332097e+06  3.653739     2.522161e-06

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="d8116680-bda5-403d-9b6d-68ac4b607330" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="e8b57c08-ff10-4717-9a57-d6787c4d852e" style="padding-left: 10px;" text = ""/>
#                      aic           bic  kl_div  sumsquare_error
# gamma        3631.421535 -1.629766e+06     inf     1.230184e-08
# fatiguelife  3552.335362 -1.550751e+06     inf     5.053950e-08
# exponnorm    3503.882561 -1.526879e+06     inf     7.745161e-08
# f            3472.762389 -1.516416e+06     inf     9.336939e-08
# fisk         3368.331725 -1.509893e+06     inf     1.049415e-07

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="44215bc2-2b5a-48d8-9170-e20b7a852f50" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="d26eec83-e512-4bf5-9c5d-40e093b393b0" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# lognorm   3477.702270 -1.533178e+06     inf     6.920089e-08
# genexpon  3434.650339 -1.477797e+06     inf     1.862285e-07
# gengamma  3228.357389 -1.437681e+06     inf     3.816713e-07
# loggamma  5850.680330 -1.435382e+06     inf     3.977685e-07
# levy      3198.996026 -1.426067e+06     inf     4.699578e-07

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="1b502584-08ed-44d7-828b-49619ade2c43" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="0df038ff-d00f-4bb9-a562-4233f5be5759" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# pearson3  3631.421586 -1.629766e+06     inf     1.230185e-08
# t         3887.219173 -1.446878e+06     inf     3.238514e-07
# logistic  4263.579399 -1.445763e+06     inf     3.304408e-07
# powerlaw  2982.775343 -1.378593e+06     inf     1.098168e-06
# pareto    3315.585448 -1.312119e+06     inf     3.605222e-06

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi','gamma', 'lognorm', 'pearson3'], bins=150)

f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="9a17a23a-c8e0-4d5a-bc33-6b99748f5e1c" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="5d86c50d-4a73-4e27-85b5-7b9aa1d064cc" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3633.421722 -1.629756e+06     inf     1.230182e-08
# gamma     3631.421535 -1.629766e+06     inf     1.230184e-08
# pearson3  3631.421586 -1.629766e+06     inf     1.230185e-08
# chi       4276.436534 -1.572860e+06     inf     3.403521e-08
# lognorm   3477.702270 -1.533178e+06     inf     6.920089e-08

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 140)

# %%
rides = df["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="ef12561b-0059-4c24-8fb5-07732e2f20e2" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="e78640d6-d47a-4d5c-9d07-d3e167b0fe5a" style="padding-left: 10px;" text = ""/>
#                  aic           bic    kl_div  sumsquare_error
# burr     2543.451265 -1.162796e+06  0.025587         0.000052
# lognorm  2689.998464 -1.071544e+06  0.086864         0.000266
# gamma    3049.369003 -9.927395e+05  0.263940         0.001090
# beta     3038.465742 -9.921588e+05  0.265952         0.001101
# norm     4428.234077 -9.421483e+05  0.838998         0.002694

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'burr': (1.303675671879739,
#   37.059038519378745,
#   0.14849392706186545,
#   1.0005628861292242)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.303675671879739,
#   37.059038519378745,
#   0.14849392706186545,
#   1.0005628861292242)}

# %%
f.get_best(method = 'bic')
# Out:
# {'burr': (1.303675671879739,
#   37.059038519378745,
#   0.14849392706186545,
#   1.0005628861292242)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="20ec7373-025c-4e8d-915b-b9be71cef922" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="fd27017a-1650-41b6-8968-d2e28f3b067f" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# burr      2543.451265 -1.162796e+06  0.025587         0.000052
# alpha     2469.323640 -1.098575e+06  0.032692         0.000164
# beta      3038.465742 -9.921588e+05  0.265952         0.001101
# norm      4428.234077 -9.421483e+05  0.838998         0.002694
# bradford  1922.320712 -9.414104e+05  1.177880         0.002729

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="abc5979f-f772-44b8-ba38-c232da873767" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="3093c91c-ef53-4f1d-94fb-b456775ca1f5" style="padding-left: 10px;" text = ""/>
#                 aic           bic    kl_div  sumsquare_error
# dgamma  3001.327517 -1.006716e+06  0.103088         0.000849
# expon   3252.581393 -1.000596e+06  0.260076         0.000947
# chi2    3041.757109 -9.928619e+05  0.264816         0.001087
# chi     3012.686828 -9.674460e+05  0.434170         0.001713
# cosine  2093.914078 -9.282702e+05  1.584716         0.003452

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="62062e2c-5c62-4008-8afe-95f7ee2902c7" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="e94ea0a7-2e25-4d36-b76a-a4c9016d36d1" style="padding-left: 10px;" text = ""/>
#                      aic           bic    kl_div  sumsquare_error
# f            2547.548258 -1.159434e+06  0.027453         0.000055
# fisk         2663.711125 -1.097685e+06  0.061088         0.000167
# fatiguelife  2743.593432 -1.048764e+06  0.132784         0.000400
# exponnorm    3363.386376 -1.023457e+06  0.220406         0.000629
# gamma        3049.369003 -9.927395e+05  0.263940         0.001090

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="39406109-e8a2-4035-83a9-dc31271bb2c3" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="e78182b2-41a2-402e-99d7-36dc87d2299f" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# lognorm   2689.998464 -1.071544e+06  0.086864         0.000266
# levy      2243.366812 -1.007683e+06  0.182599         0.000834
# genexpon  3258.578568 -1.000563e+06  0.260077         0.000947
# gengamma  2798.016070 -9.957264e+05  0.224009         0.001033
# loggamma  4027.359601 -9.406628e+05  0.864511         0.002766

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="d3ea481f-6a0f-41bd-9bca-98b4e2c0a288" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="2c6dca62-12b3-4dad-aeec-bfedd1685425" style="padding-left: 10px;" text = ""/>
#                   aic           bic    kl_div  sumsquare_error
# t         2743.084350 -1.059086e+06  0.073422         0.000333
# pearson3  3073.547371 -9.932431e+05  0.261977         0.001080
# logistic  4316.732986 -9.621508e+05  0.494374         0.001884
# powerlaw  1997.625182 -9.503000e+05  0.836638         0.002328
# pareto    2365.045083 -9.153609e+05  0.665655         0.004348

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['alpha','burr','f', 'lognorm'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="66808878-dbb2-4632-ba1d-322d327fafca" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="54bb25b2-3e42-45b3-a979-5f085fcd8d07" style="padding-left: 10px;" text = ""/>
#                  aic           bic    kl_div  sumsquare_error
# burr     2543.451265 -1.162796e+06  0.025587         0.000052
# f        2547.548258 -1.159434e+06  0.027453         0.000055
# alpha    2469.323640 -1.098575e+06  0.032692         0.000164
# lognorm  2689.998464 -1.071544e+06  0.086864         0.000266
