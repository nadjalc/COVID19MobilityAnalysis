# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2021-02.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 150)

# %%
distance = df["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="b8d0b91c-f838-46c5-b71b-57d2ae828a6a" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="90a13252-d86c-4714-8bd2-4eda11b43c8c" style="padding-left: 10px;" text = ""/>
#                  aic            bic  kl_div  sumsquare_error
# beta     3629.661501 -722370.700032     inf     1.948197e-08
# gamma    3627.661212 -722380.849927     inf     1.948198e-08
# burr     3391.484216 -689684.395687     inf     6.889150e-08
# norm     5871.544940 -640550.004784     inf     4.603275e-07
# lognorm  3716.647121 -598092.603501     inf     2.373587e-06

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'beta': (1.3516177991508473,
#   8826386.64165035,
#   195.97767920110016,
#   11610960841.6214)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (2.61633304452618,
#   0.5581270323142844,
#   -3.7930224223905675,
#   2318.4664237458837)}

# %%
f.get_best(method = 'bic')
# Out:
# {'gamma': (1.3516179721807582, 195.97765942064837, 1315.4826246177977)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="f2777713-afe2-454a-96a6-5e20142f63a7" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="8fa35247-fe17-4af1-b340-e93af978ed76" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# beta      3629.661501 -722370.700032     inf     1.948197e-08
# burr      3391.484216 -689684.395687     inf     6.889150e-08
# norm      5871.544940 -640550.004784     inf     4.603275e-07
# alpha     3292.479919 -632187.028956     inf     6.356846e-07
# bradford  2901.009847 -615687.747998     inf     1.202619e-06

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="d4baebc5-4171-4f5b-8a16-fbbee2b1de15" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="f586b123-72df-4366-a3ea-984cd03ee773" style="padding-left: 10px;" text = ""/>
#                   aic            bic   kl_div  sumsquare_error
# chi       4340.252525 -707170.926063      inf     3.506565e-08
# expon     3470.785235 -671352.836733      inf     1.400045e-07
# dgamma    4212.071294 -643743.384717      inf     4.067298e-07
# cosine    3116.725078 -608401.256931      inf     1.594332e-06
# chi2    233795.759326 -594809.226983  3.53167     2.694672e-06

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="5299df09-c499-45a4-8826-7e28736d5cf7" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="78d0f5de-f6a4-4265-9d8a-0111390888df" style="padding-left: 10px;" text = ""/>
#                      aic            bic  kl_div  sumsquare_error
# gamma        3627.661212 -722380.849927     inf     1.948198e-08
# f            3654.547983 -691996.218799     inf     6.300416e-08
# fatiguelife  3546.867798 -688873.861381     inf     7.111126e-08
# exponnorm    3503.640839 -684267.172863     inf     8.496627e-08
# fisk         3358.808255 -672667.182122     inf     1.330193e-07

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="502a1ba9-7417-41bc-9f03-64a3584fcdd0" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="0bcd6c9f-d553-4f52-932c-23cb3b1650e9" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# genexpon  3477.257686 -671259.442854     inf     1.403453e-07
# gengamma  3475.492743 -671094.089460     inf     1.413003e-07
# levy      3198.932146 -640507.950372     inf     4.610762e-07
# loggamma  5837.145009 -640251.017520     inf     4.654939e-07
# lognorm   3716.647121 -598092.603501     inf     2.373587e-06

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="10b0654e-7c56-4f72-919c-852dc8fdf3a7" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="19d046af-4c1d-49d0-8ce5-3246a2dce7dc" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# pearson3  3627.661267 -722380.839281     inf     1.948198e-08
# logistic  4284.628562 -644046.239562     inf     4.021556e-07
# t         4688.141557 -641030.341222     inf     4.516849e-07
# powerlaw  2977.612514 -617856.601956     inf     1.105939e-06
# pareto    3311.584066 -587580.952638     inf     3.562944e-06

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi','gamma', 'gengamma', 'pearson3'], bins=150)

f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="7b7c336a-1c8e-4083-8c7b-866760b64489" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="526bf41a-2dc9-490f-8b26-3df9028510f3" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# beta      3629.661501 -722370.700032     inf     1.948197e-08
# gamma     3627.661212 -722380.849927     inf     1.948198e-08
# pearson3  3627.661267 -722380.839281     inf     1.948198e-08
# chi       4340.252525 -707170.926063     inf     3.506565e-08
# gengamma  3475.492743 -671094.089460     inf     1.413003e-07

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 140)

# %%
rides = df["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="5def0706-faa6-4d52-92b3-a05a8821558c" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="cea9d27d-4d11-42e4-b815-c2188ba477d0" style="padding-left: 10px;" text = ""/>
#                  aic            bic  kl_div  sumsquare_error
# burr     2551.302683 -518136.488916     inf         0.000052
# lognorm  2692.165513 -475580.728605     inf         0.000270
# beta     3088.213560 -440797.411022     inf         0.001035
# gamma    3028.276570 -440616.669695     inf         0.001043
# norm     4718.796027 -415687.302675     inf         0.002733

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'burr': (1.2963090319957906,
#   19.397862349896954,
#   0.061393559309427984,
#   1.560727009060554)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.2963090319957906,
#   19.397862349896954,
#   0.061393559309427984,
#   1.560727009060554)}

# %%
f.get_best(method = 'bic')
# Out:
# {'burr': (1.2963090319957906,
#   19.397862349896954,
#   0.061393559309427984,
#   1.560727009060554)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="f63967bc-d501-43ba-bc88-e901372d3654" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="e2243e10-4ecd-4dce-a965-a5499b067ac5" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# burr      2551.302683 -518136.488916     inf         0.000052
# alpha     2488.487392 -484609.677410     inf         0.000190
# beta      3088.213560 -440797.411022     inf         0.001035
# norm      4718.796027 -415687.302675     inf         0.002733
# bradford  1860.036378 -411116.965369     inf         0.003260

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="094adc2f-d479-4bca-a7cb-8415f88c448f" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="a51e0193-ac2d-42f4-a97f-4aa26a109a3e" style="padding-left: 10px;" text = ""/>
#                 aic            bic  kl_div  sumsquare_error
# expon   3338.220212 -445010.077614     inf         0.000880
# dgamma  3003.917858 -444170.847881     inf         0.000909
# chi2    3061.601235 -440964.321148     inf         0.001029
# chi     3191.363705 -429457.239573     inf         0.001605
# cosine  2094.473136 -408986.992626     inf         0.003541

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="5dec4048-95bc-4867-a0a2-94ba25c7d651" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="5cee3fbe-ab51-4b30-b4e8-f9850cfff778" style="padding-left: 10px;" text = ""/>
#                      aic            bic  kl_div  sumsquare_error
# f            2557.196549 -515744.148057     inf         0.000057
# fisk         2661.645911 -490199.774249     inf         0.000153
# fatiguelife  2774.600135 -463279.451800     inf         0.000434
# exponnorm    3441.113884 -453152.414261     inf         0.000642
# gamma        3028.276570 -440616.669695     inf         0.001043

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="57ada45e-ac98-448c-99ba-a83eaa501bb9" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="05dbde5a-160c-473c-a503-21ccbd219a10" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# lognorm   2692.165513 -475580.728605     inf         0.000270
# genexpon  3344.216062 -444979.537086     inf         0.000880
# levy      2253.054821 -444670.925337     inf         0.000892
# gengamma  2831.017974 -442708.744925     inf         0.000961
# loggamma  4525.557734 -415261.418102     inf         0.002777

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="2b9e4d1f-9ac7-49f2-9645-b1429fa39536" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="b864a39c-8c86-4c6e-9af9-622495e6b804" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# t         2751.443061 -471869.936307     inf         0.000312
# pearson3  3174.206034 -441398.769872     inf         0.001012
# logistic  4438.315637 -425020.737395     inf         0.001906
# powerlaw  2003.949020 -420562.260476     inf         0.002263
# pareto    2369.739433 -405516.302763     inf         0.004047

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['alpha','burr','lognorm', 'f'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="eea7f850-0a90-4b22-b950-ed08b5205339" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="c835697d-86ea-4be6-8356-3a0fc7124ac2" style="padding-left: 10px;" text = ""/>
#                  aic            bic  kl_div  sumsquare_error
# burr     2551.302683 -518136.488916     inf         0.000052
# f        2557.196549 -515744.148057     inf         0.000057
# alpha    2488.487392 -484609.677410     inf         0.000190
# lognorm  2692.165513 -475580.728605     inf         0.000270
