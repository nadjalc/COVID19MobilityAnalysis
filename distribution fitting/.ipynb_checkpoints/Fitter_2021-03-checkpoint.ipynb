# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from fitter import Fitter, get_common_distributions, get_distributions

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# %%
url = "/bigdata/jelicicna/output_datasets/anlysis_data_nextbike_2021-03.csv"
df = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# # Distances Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['distance'], bins = 150)

# %%
distance = df["distance"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(distance,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="4176c6b6-e207-4740-8433-9bbf021b4e40" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="8e0ec2ed-0c69-49bd-82e2-3d7ff3914732" style="padding-left: 10px;" text = ""/>
#                  aic           bic  kl_div  sumsquare_error
# beta     3665.278970 -1.001209e+06     inf     1.020907e-08
# gamma    3410.902623 -9.782758e+05     inf     1.977603e-08
# burr     3310.151281 -9.158573e+05     inf     1.194590e-07
# norm     4819.269601 -8.637558e+05     inf     5.364972e-07
# lognorm  4154.040049 -7.982542e+05     inf     3.541885e-06

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'beta': (1.2203031077984126,
#   9.005145519678724,
#   199.16529772541273,
#   14893.316334316987)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (2.9543630916276946,
#   0.5047461656071983,
#   -5.711881146607023,
#   2437.485254305534)}

# %%
f.get_best(method = 'bic')
# Out:
# {'beta': (1.2203031077984126,
#   9.005145519678724,
#   199.16529772541273,
#   14893.316334316987)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(distance,
           distributions= ['alpha','beta','norm','bradford','burr'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="2877badc-ac20-47d7-9d86-3248e1177c38" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="192b3b1f-babc-4071-8109-56a37f6d6e55" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3665.278970 -1.001209e+06     inf     1.020907e-08
# burr      3310.151281 -9.158573e+05     inf     1.194590e-07
# norm      4819.269601 -8.637558e+05     inf     5.364972e-07
# bradford  2912.421341 -8.572671e+05     inf     6.466160e-07
# alpha     3208.122241 -8.539763e+05     inf     7.109400e-07

# %%
f = Fitter(distance,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="70b23f8e-b393-41b5-9f8c-30be811f45c8" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="a57fa75e-1e0b-4e30-9d67-96e9b730e89c" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# chi       3831.217548 -950597.584857       inf     4.390876e-08
# expon     3292.958659 -902458.281054       inf     1.758647e-07
# dgamma    3852.995898 -870435.684809       inf     4.424180e-07
# cosine    3060.011780 -824564.674439       inf     1.659858e-06
# chi2    355079.250588 -802377.958302  3.747632     3.145012e-06

# %%
f = Fitter(distance,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="4493fbf8-ca95-425b-857e-e85f8d2eae7c" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="43a84f9e-6ed1-4c7d-a72f-4730c88e8303" style="padding-left: 10px;" text = ""/>
#                      aic            bic  kl_div  sumsquare_error
# gamma        3410.902623 -978275.800590     inf     1.977603e-08
# f            3459.042361 -935539.680887     inf     6.774549e-08
# exponnorm    3322.444070 -924831.122511     inf     9.226485e-08
# fisk         3245.716104 -909332.715715     inf     1.442147e-07
# fatiguelife  3276.396854 -863647.545324     inf     5.380108e-07

# %%
f = Fitter(distance,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="a2328859-0688-4c97-834a-0e1261b99570" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="60794a58-1f1b-4047-99f9-89a76009455a" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# gengamma  3316.486438 -921853.260800     inf     1.005022e-07
# levy      3135.412381 -863382.022954     inf     5.423068e-07
# loggamma  4767.771632 -863192.738488     inf     5.451089e-07
# genexpon  3562.558894 -859923.795775     inf     5.985971e-07
# lognorm   4154.040049 -798254.155577     inf     3.541885e-06

# %%
f = Fitter(distance,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins=150)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="8cd6e8c7-5b1f-458e-a7d4-801ca19b1e65" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="73dbd3fa-8567-4b9d-9ac1-ad87c02a6cb1" style="padding-left: 10px;" text = ""/>
#                   aic            bic  kl_div  sumsquare_error
# pearson3  3410.902588 -978275.810847     inf     1.977603e-08
# t         3705.725022 -869075.661518     inf     4.601023e-07
# logistic  3903.409279 -868627.038252     inf     4.662298e-07
# powerlaw  2948.019146 -830561.828712     inf     1.395988e-06
# pareto    3245.626366 -791406.030383     inf     4.314630e-06

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(distance,
           distributions= ['beta','chi','gamma', 'gengamma', 'pearson3'], bins=150)

f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="c7d0eb66-4889-4374-9483-224db08c37e3" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="9086658e-b640-4263-87f9-c0e4e3d69f8e" style="padding-left: 10px;" text = ""/>
#                   aic           bic  kl_div  sumsquare_error
# beta      3665.278970 -1.001209e+06     inf     1.020907e-08
# pearson3  3410.902588 -9.782758e+05     inf     1.977603e-08
# gamma     3410.902623 -9.782758e+05     inf     1.977603e-08
# chi       3831.217548 -9.505976e+05     inf     4.390876e-08
# gengamma  3316.486438 -9.218533e+05     inf     1.005022e-07

# %% [markdown]
# ## Rides Analysis

# %% [markdown]
# ### Inital view of the data

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1.5)
sns.distplot(df['ride_time'], bins = 140)

# %%
rides = df["ride_time"].values

# %% [markdown]
# #### 5 common distributions

# %%
f = Fitter(rides,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="74750f85-05ee-4bd1-91a7-65a0b80b36c4" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="d4c4b293-2adc-4d38-8de3-53d8cec6ff4f" style="padding-left: 10px;" text = ""/>
#                  aic            bic    kl_div  sumsquare_error
# burr     2576.662503 -714044.867876  0.024843         0.000040
# lognorm  2740.320944 -649843.787190  0.077369         0.000255
# gamma    3207.327739 -600846.106903  0.239910         0.001047
# beta     3196.909897 -600807.300395  0.242029         0.001048
# norm     4945.189636 -566333.952421  0.858003         0.002831

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'burr': (1.3396417500690196,
#   14.939121897739415,
#   0.08739832421580043,
#   2.022593072646128)}

# %%
f.get_best(method = 'aic')
# Out:
# {'burr': (1.3396417500690196,
#   14.939121897739415,
#   0.08739832421580043,
#   2.022593072646128)}

# %%
f.get_best(method = 'bic')
# Out:
# {'burr': (1.3396417500690196,
#   14.939121897739415,
#   0.08739832421580043,
#   2.022593072646128)}

# %% [markdown]
# ### Fitting distributions with regards to the result of 5 from above including variety of common distributions

# %%
f = Fitter(rides,
           distributions= ['alpha','beta','norm','bradford','burr'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="2ced66a4-d7c9-47d9-8e4d-dd1ace6266cc" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="9bae2b7f-2918-4394-9b0e-e8e716bb4d07" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# alpha     2538.663016 -718700.024703  0.020126         0.000035
# burr      2576.662503 -714044.867876  0.024843         0.000040
# beta      3196.909897 -600807.300395  0.242029         0.001048
# bradford  2019.551053 -580157.100081  0.670826         0.001901
# norm      4945.189636 -566333.952421  0.858003         0.002831

# %%
f = Fitter(rides,
           distributions= ['chi','chi2','cosine','dgamma','expon'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="c180cac5-2a4c-4a4f-8368-5c183183359a" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="86fe1163-fc5c-41ee-a7ca-e6f70398a255" style="padding-left: 10px;" text = ""/>
#                 aic            bic    kl_div  sumsquare_error
# dgamma  3648.825201 -615225.250933  0.114403         0.000692
# expon   3430.557502 -605796.663258  0.239236         0.000908
# chi2    3177.512621 -600533.288361  0.242687         0.001056
# chi     3323.695523 -584130.590097  0.414628         0.001695
# cosine  2094.508616 -556997.784154  1.705362         0.003706

# %%
f = Fitter(rides,
           distributions= ['exponnorm','f','fatiguelife','fisk','gamma'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="53e0920c-19f8-459b-a1d0-eb643b3c1638" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="f7a02c8a-af0a-46f8-b699-fd2313243aa4" style="padding-left: 10px;" text = ""/>
#                      aic            bic    kl_div  sumsquare_error
# f            2583.597985 -709724.980329  0.027330         0.000045
# fisk         2694.469069 -670887.024179  0.049370         0.000139
# fatiguelife  2846.963051 -631907.166870  0.132417         0.000428
# exponnorm    3549.187622 -618923.196140  0.208374         0.000622
# gamma        3207.327739 -600846.106903  0.239910         0.001047

# %%
f = Fitter(rides,
           distributions= ['genexpon','gengamma','levy','loggamma','lognorm'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="3b67e9ac-abf8-44c7-ac21-756d64d00615" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="862789e8-0e28-4219-b9c6-f4a04677b11e" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# lognorm   2740.320944 -649843.787190  0.077369         0.000255
# genexpon  3436.511522 -605764.545739  0.239242         0.000908
# levy      2252.616832 -604215.480192  0.194918         0.000950
# gengamma  2888.053859 -600499.240705  0.237359         0.001057
# loggamma  4565.777497 -565482.230781  0.885245         0.002901

# %%
f = Fitter(rides,
           distributions= ['logistic','pareto','pearson3','powerlaw','t'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="fb64b101-86de-4951-b797-9a6389de2a42" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="58b1ef9a-40b9-411f-9826-fa7ba15dcdae" style="padding-left: 10px;" text = ""/>
#                   aic            bic    kl_div  sumsquare_error
# t         2775.767648 -639213.362901  0.068813         0.000347
# pearson3  3380.458478 -603007.431357  0.226613         0.000984
# logistic  4665.844835 -580114.350797  0.463375         0.001903
# powerlaw  2005.046997 -572081.977851  0.870948         0.002398
# pareto    2371.326331 -552395.349708  0.576917         0.004230

# %% [markdown]
# ### 5 best distributions chosen from the above analysis

# %%
f = Fitter(rides,
           distributions= ['alpha','burr','lognorm', 'f'], bins = 140)
f.fit()
f.summary()
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="d43bde02-403d-432a-b0f7-42ffc480ec57" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="b315aca9-14bb-4190-8bfb-77fc7402f5f3" style="padding-left: 10px;" text = ""/>
#                  aic            bic    kl_div  sumsquare_error
# alpha    2538.663016 -718700.024703  0.020126         0.000035
# burr     2576.662503 -714044.867876  0.024843         0.000040
# f        2583.597985 -709724.980329  0.027330         0.000045
# lognorm  2740.320944 -649843.787190  0.077369         0.000255
